# %% [markdown]
# <a href="https://colab.research.google.com/github/emanueltay/Optimal_Subtitle_Placement/blob/main/caption_placement_preposition_testing_21_mar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/optimal_subtitle_copied.zip -d /content/
# Out:
# Archive:  /content/optimal_subtitle_copied.zip
#    creating: /content/optimal_subtitle_copied/
#    creating: /content/optimal_subtitle_copied/TTML_file/
#   inflating: /content/optimal_subtitle_copied/TTML_file/test_video_3_eng.ttml
#   inflating: /content/optimal_subtitle_copied/subtitle_positions_ttml.json
#    creating: /content/optimal_subtitle_copied/Font/
#   inflating: /content/optimal_subtitle_copied/Font/GoNotoKurrent-Regular.ttf
#   inflating: /content/optimal_subtitle_copied/Font/OpenSans-Italic-VariableFont_wdth,wght.ttf
#   inflating: /content/optimal_subtitle_copied/Font/OpenSans-VariableFont_wdth,wght.ttf
#   inflating: /content/optimal_subtitle_copied/Font/DejaVuSans-Bold.ttf
#   inflating: /content/optimal_subtitle_copied/Font/NotoNaskhArabic-Regular.ttf
#   inflating: /content/optimal_subtitle_copied/Font/NotoSansDevanagari-Regular.ttf
#   inflating: /content/optimal_subtitle_copied/Font/NotoSansCJK-Regular.ttc
#   inflating: /content/optimal_subtitle_copied/Font/NotoSansThai-Regular.ttf
#   inflating: /content/optimal_subtitle_copied/Font/NotoSans-Regular.ttf
#   inflating: /content/optimal_subtitle_copied/test_video_1.mp4
#   inflating: /content/optimal_subtitle_copied/caption_placement_preposition.ipynb
#    creating: /content/optimal_subtitle_copied/SRT_file/
#   inflating: /content/optimal_subtitle_copied/SRT_file/test_video_4_chinese.srt
#   inflating: /content/optimal_subtitle_copied/SRT_file/test_video_3_eng.srt
#   inflating: /content/optimal_subtitle_copied/SRT_file/test_video_4_hebrew.srt
#   inflating: /content/optimal_subtitle_copied/SRT_file/test_video_4_thai.srt
#   inflating: /content/optimal_subtitle_copied/SRT_file/test_video_4_eng.srt
#   inflating: /content/optimal_subtitle_copied/SRT_file/test_long_video_17_eng.srt
#   inflating: /content/optimal_subtitle_copied/SRT_file/test_video_4_japan.srt
#   inflating: /content/optimal_subtitle_copied/SRT_file/test_video_4_korea.srt
#   inflating: /content/optimal_subtitle_copied/SRT_file/test_video_4_arabic.srt
#   inflating: /content/optimal_subtitle_copied/news_video_subtitle_positions.json
#   inflating: /content/optimal_subtitle_copied/best.pt
#   inflating: /content/optimal_subtitle_copied/test_video_3.mp4
#   inflating: /content/optimal_subtitle_copied/test_video_5.mp4
#   inflating: /content/optimal_subtitle_copied/test_video_4.mp4
#   inflating: /content/optimal_subtitle_copied/test_video_2.mp4
#   inflating: /content/optimal_subtitle_copied/subtitle_positions_updated.json
#   inflating: /content/optimal_subtitle_copied/subtitle_pre_positions(updated).json
#   inflating: /content/optimal_subtitle_copied/best_100.pt

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.94-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.94-py3-none-any.whl (949 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 48.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 87.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 90.6 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.94 ultralytics-thop-2.0.14

# %% [markdown]
# ### Detect Key Objects in the Frame

# %%
# ! pip install ultralytics

from ultralytics import YOLO
import cv2
import torch

# Load the trained model
model = YOLO("/content/optimal_subtitle_copied/best_100.pt")
# model = YOLO("/content/optimal_subtitle_copied/best.pt")

# # ✅ Automatically select GPU if available
device = "cuda" if torch.cuda.is_available() else "cpu"

# # ✅ Move model to the selected device
model.to(device).float()  # Use FP32 (FP16 can cause issues on CPU)

# ✅ Optimize PyTorch settings
torch.backends.cudnn.benchmark = True  # Optimize for fixed-size inputs
torch.backends.cudnn.enabled = True
torch.set_num_threads(torch.get_num_threads())  # Use optimal number of CPU threads


def detect_objects(frames):
    """
    Perform batch object detection on multiple frames.

    Parameters:
        frames (list): List of frames (each a NumPy array).

    Returns:
        list: A list containing detections for each frame.
              Each element is a NumPy array of detections.
    """
    # ✅ Run the model in batch mode
    results = model(frames, batch=len(frames), imgsz=640, verbose=True)  # Run batch inference

    # ✅ Extract detections for each frame
    batch_detections = []
    for result in results:
        detections = result.boxes.data.cpu().numpy()  # Convert detections to NumPy array
        batch_detections.append(detections)

    return batch_detections  # List of detections per frame

# %% [markdown]
# ### Define Safe Zones for Subtitle Placement

# %%
import json

# ✅ Global in-memory cache for dynamic & shifted safe zones
safe_zone_cache = {}
used_safe_zones = {}  # Dictionary to store all assigned safe zones

def calculate_safe_zone_with_prepositions_test_new(frame_width, frame_height, detections, pre_positions, subtitle_height, margin, shift_x=20):
    """
    Calculate the safe zone for subtitle placement using pre-defined positions.
    If blocked, it attempts to shift left/right before moving vertically.
    If no predefined position works, falls back to a dynamic safe zone and caches it in memory.

    Returns:
        tuple: (position_name, coordinates)
    """

    def zones_overlap(zone1, zone2):
        """Checks if two zones overlap."""
        x1a, y1a, x2a, y2a = zone1
        x1b, y1b, x2b, y2b = zone2
        return not (x2a < x1b or x1a > x2b or y2a < y1b or y1a > y2b)

    # ✅ Step 1: Check if we already computed a safe zone for this frame in memory
    cache_key = (frame_width, frame_height, tuple(tuple(d) for d in detections))  # Unique key per resolution + detections
    if cache_key in safe_zone_cache:
        return safe_zone_cache[cache_key]  # Return cached value

    # ✅ Step 2: Try Predefined Positions
    for position_name, position in sorted(pre_positions.items(), key=lambda x: x[1].get("priority", 0), reverse=True):
        x1, y1, x2, y2 = position["coordinates"]

        # Check if the original pre-position is available
        if not any(zones_overlap((x1, y1, x2, y2), detection[:4]) for detection in detections):
            safe_zone_cache[cache_key] = (position_name, (x1, y1, x2, y2))  # ✅ Store in cache

            # ✅ Store in used safe zones for JSON output
            used_safe_zones[position_name] = {
                "coordinates": [x1, y1, x2, y2]
            }
            return (position_name, (x1, y1, x2, y2))

        min_width = max(0.6 * frame_width, 600)  # 60% of frame width, but at least 600px

        # ✅ Try shifting left and right before moving to fallback
        for shift_dir in ["left", "right"]:
            shift_attempts = 0
            while shift_attempts < 10:  # Try shifting multiple times
                if shift_dir == "left":
                    new_x1, new_x2 = max(0, x1 - shift_x), max(min_width, x2 - shift_x)
                else:
                    new_x1, new_x2 = min(frame_width - min_width, x1 + shift_x), min(frame_width, x2 + shift_x)

                shifted_zone = (new_x1, y1, new_x2, y2)

                if new_x2 > new_x1 and not any(zones_overlap(shifted_zone, detection[:4]) for detection in detections):
                    safe_zone_cache[cache_key] = (f"shifted_{position_name}", shifted_zone)  # ✅ Store shifted result in cache

                    # ✅ Store in used safe zones with "shifted_" prefix
                    used_safe_zones[f"shifted_{position_name}"] = {
                        "coordinates": [new_x1, y1, new_x2, y2]
                    }
                    return (f"shifted_{position_name}", shifted_zone)  # Return valid shifted zone

                shift_attempts += 1
                shift_x *= 1.5  # Increase shift size if first shift attempt fails

    # ✅ Step 3: No Predefined Positions Worked, Try Dynamic Safe Zone
    fallback_position_name = "fallback_bottom"
    proposed_safe_zone = (0, frame_height - subtitle_height - margin, frame_width, frame_height - margin)

    while True:
        if all(not zones_overlap(proposed_safe_zone, (int(d[0]), int(d[1]), int(d[2]), int(d[3]))) for d in detections):
            safe_zone_cache[cache_key] = (fallback_position_name, proposed_safe_zone)  # ✅ Store in cache

            # ✅ Store dynamic position as "fallback_bottom"
            used_safe_zones[fallback_position_name] = {
                "coordinates": list(proposed_safe_zone)
            }
            return (fallback_position_name, proposed_safe_zone)

        # Try shifting up
        x1, y1, x2, y2 = proposed_safe_zone
        new_y1 = y1 - subtitle_height - margin
        new_y2 = y2 - subtitle_height - margin

        if new_y1 < 0:
            break  # No valid space above, fallback required

        proposed_safe_zone = (x1, new_y1, x2, new_y2)

    # ✅ Step 4: Final Fallback to Top and Cache It
    fallback_position_name = "fallback_top"
    final_safe_zone = (0, margin, frame_width, subtitle_height + margin)
    safe_zone_cache[cache_key] = (fallback_position_name, final_safe_zone)  # ✅ Store fallback result in cache

    # ✅ Store fallback position as "fallback_top"
    used_safe_zones[fallback_position_name] = {
        "coordinates": list(final_safe_zone)
    }

    print(fallback_position_name, final_safe_zone)
    return (fallback_position_name, final_safe_zone)

def get_used_safe_zones():
    """
    Returns the used safe zones as a dictionary without the "priority" field.
    This can be directly used for updating the TTML layout.
    """
    return {
        key: {"coordinates": value["coordinates"]}
        for key, value in used_safe_zones.items()
    }

# %% [markdown]
# ### Subtitle size and margin

# %%
def get_subtitle_size(frame_height):
    """
    Dynamically calculate subtitle height and margin based on frame resolution.

    Parameters:
        frame_height (int): Height of the video frame.

    Returns:
        tuple: (subtitle_height, margin)
    """
    subtitle_height = max(0.07 * frame_height, 18)  # Minimum 18px for readability
    margin = max(0.02 * frame_height, 5)  # Minimum 5px to avoid text touching edges

    return int(subtitle_height), int(margin)

# %% [markdown]
# ### Subtitle character calculation

# %%
# !pip install arabic-reshaper
# Out:
# Collecting arabic-reshaper
#   Downloading arabic_reshaper-3.0.0-py3-none-any.whl.metadata (12 kB)
# Downloading arabic_reshaper-3.0.0-py3-none-any.whl (20 kB)
# Installing collected packages: arabic-reshaper
# Successfully installed arabic-reshaper-3.0.0

# %%
# !pip install python-bidi
# Out:
# Collecting python-bidi
#   Downloading python_bidi-0.6.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Downloading python_bidi-0.6.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (292 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.9/292.9 kB 13.1 MB/s eta 0:00:00
# Installing collected packages: python-bidi
# Successfully installed python-bidi-0.6.6

# %%
import cv2
import re
import textwrap
import numpy as np
import arabic_reshaper
from bidi.algorithm import get_display
from PIL import ImageFont, ImageDraw, Image

## universal font that fits all languages
def get_font(font_size):
    """
    Loads the universal OpenSans font.

    Parameters:
        font_size (int): The desired font size.

    Returns:
        PIL.ImageFont: The loaded font.
    """
    font_path = "/content/optimal_subtitle_copied/Font/GoNotoKurrent-Regular.ttf"
    return ImageFont.truetype(font_path, font_size)

# **2️⃣ Function to Detect Language Type**
def detect_language(text):
    """
    Detects if the text contains Latin, CJK, Arabic, or Indic characters.

    Returns:
        str: "latin", "cjk", "arabic", "indic", "thai" based on detected script.
    """

    # Extract the first two words
    words = re.findall(r'\b\w+\b', text)  # Split text into words
    text_snippet = " ".join(words[:2])  # Take only the first two words

    if any("\u0600" <= ch <= "\u06FF" for ch in text_snippet):  # Arabic script range
        return "arabic"
    elif any("\u4E00" <= ch <= "\u9FFF" for ch in text_snippet):  # Chinese script range
        return "cjk"
    elif any("\u3040" <= ch <= "\u30FF" for ch in text_snippet):  # Japanese script range
        return "cjk"
    elif any("\uAC00" <= ch <= "\uD7AF" for ch in text_snippet):  # Korean script range
        return "cjk"
    elif any("\u0900" <= ch <= "\u097F" for ch in text_snippet):  # Devanagari script (Hindi, Marathi, Sanskrit)
        return "indic"
    elif any("\u0E00" <= ch <= "\u0E7F" for ch in text_snippet):  # Thai script
        return "thai"
    return "latin"  # Default to Latin if nothing is detected

# **3️⃣ Main Subtitle Rendering Function**
def render_subtitle_multi_new(frame, subtitle_text, safe_zone, frame_width, frame_height, max_chars_per_line=40, opacity=0.8):
    """
    Render multi-line subtitles centered within the safe zone with a semi-transparent background.

    Parameters:
        frame (numpy array): The frame on which to render subtitles.
        subtitle_text (str): The text to display.
        safe_zone (tuple): (x1, y1, x2, y2) defining subtitle placement.
        frame_width (int): Width of the frame.
        frame_height (int): Height of the frame.
        opacity (float): Background opacity (0 = fully transparent, 1 = fully opaque).

    Returns:
        numpy array: The frame with subtitles rendered at an optimal position.
    """
    x1, y1, x2, y2 = safe_zone
    language = detect_language(subtitle_text)  # **Detect language**
    font_size = 28 if language == "cjk" else 26  # Adjust font size for CJK characters
    font = get_font(font_size)

    # **Handle Right-to-Left (RTL) text (e.g., Arabic)**
    if language == "arabic":
        subtitle_text = get_display(arabic_reshaper.reshape(subtitle_text))

    # **Calculate max width available for text**
    max_text_width = x2 - x1 - 30  # Ensure padding (30)
    # print("Max width in pixels:", max_text_width)

    # **Estimate Average Character Width Dynamically Using Subtitle Text**
    if len(subtitle_text) > 0:
        char_width = sum(font.getbbox(char)[2] - font.getbbox(char)[0] for char in subtitle_text) / len(subtitle_text)
    else:
        char_width = font_size // 2  # Fallback for empty text

    # **Determine Maximum Characters That Fit in Safe Zone**
    estimated_max_chars = max_text_width // char_width

    # **Use the Minimum of User-Defined or Estimated Max Chars**
    final_max_chars_per_line = min(estimated_max_chars, max_chars_per_line)

    # **Dynamically wrap text based on max character limit**
    wrapped_lines = []
    for line in subtitle_text.split("\n"):  # Handle existing line breaks
        new_lines = textwrap.wrap(line, width=int(final_max_chars_per_line))
        if new_lines:  # Only extend if wrapping produced text
            wrapped_lines.extend(new_lines)

    # **Fallback to prevent empty wrapped_lines**
    if not wrapped_lines:
        wrapped_lines = [" "]  # Ensures at least one blank line

    # **Measure Text Size**
    text_sizes = [font.getbbox(line) for line in wrapped_lines]
    text_width = max(size[2] - size[0] for size in text_sizes)  # Width (right - left)
    text_height = text_sizes[0][3] - text_sizes[0][1]  # Height (bottom - top)
    total_text_height = sum(size[3] - size[1] for size in text_sizes) + (len(wrapped_lines) - 1) * 10  # Extra spacing

    # **Center Text Within Safe Zone**
    text_x = x1 + (x2 - x1 - text_width) // 2  # **Horizontally centered**
    text_y = y1 + (y2 - y1 - total_text_height) // 2 - 20# **Vertically centered**

    # **Define Background Box**
    bg_x1 = max(text_x - 15, 0)
    bg_y1 = max(text_y - 5, 0)
    bg_x2 = min(text_x + text_width + 15, frame_width - 1)
    bg_y2 = min(text_y + total_text_height + 15, frame_height - 1)

    # **Create Semi-Transparent Background**
    overlay = frame.copy()
    cv2.rectangle(overlay, (bg_x1, bg_y1), (bg_x2, bg_y2), (0, 0, 0), -1)  # Black background
    cv2.addWeighted(overlay, opacity, frame, 1 - opacity, 0, frame)  # Blend overlay with frame

    # **Render Text Using PIL (for better font handling)**
    frame_pil = Image.fromarray(frame)
    draw = ImageDraw.Draw(frame_pil)

    y_offset = text_y
    for line in wrapped_lines:
        line_width = font.getbbox(line)[2] - font.getbbox(line)[0]  # Measure width
        line_x = x1 + (x2 - x1 - line_width) // 2  # Center per line
        draw.text((line_x, y_offset), line, font=font, fill=(255, 255, 255))  # White text
        y_offset += text_height + 10  # Extra line spacing

    return np.array(frame_pil)  # Convert back to OpenCV format

# %% [markdown]
# ### Complete Pipeline for frames batch

# %%
import json
from collections import Counter, deque
import numpy as np
import cv2

safe_zone_history = deque(maxlen=5)  # Stores past safe zones for consistency (4)

def process_frames_batch_3fps_processed(frames, subtitles, process_fps=3, video_fps=30):
    """
    Process a batch of frames at 3 FPS:
    - Detects objects in frames sampled at 3 FPS
    - Computes one safe zone for the batch
    - Overlays subtitles using the same safe zone

    Parameters:
        frames (list): List of frames (NumPy arrays).
        subtitles (list): List of subtitles corresponding to each frame.
        video_fps (int): Original FPS of the video.
        process_fps (int): FPS at which YOLO will run.

    Returns:
        list: Processed frames with subtitles.
    """

    # ✅ Step 1: Select Frames at 3 FPS for YOLO Detection
    frame_interval = video_fps // process_fps  # Process every `frame_interval` frames
    selected_indices = list(range(0, len(frames), frame_interval))

    if not selected_indices:  # Prevent empty selection
        selected_indices = [0]  # Process at least one frame

    selected_frames = [frames[i] for i in selected_indices]  # Sampled frames for YOLO

    # ✅ Step 2: Batch Object Detection on Selected Frames
    batch_detections = detect_objects(selected_frames)  # YOLO runs only on sampled frames
    frame_height, frame_width = frames[0].shape[:2]

    # ✅ Load Predefined Safe Zones (JSON file loaded once)
    with open("/content/optimal_subtitle_copied/news_video_subtitle_positions.json", "r") as file:
        pre_positions = json.load(file).get(f"{frame_width}x{frame_height}", {})

    # ✅ Step 3: Compute Safe Zone for Each Sampled Frame
    subtitle_height, margin = get_subtitle_size(frame_height)

    # ✅ Step 3: Collect Safe Zone Positions for Each Frame in Batch
    batch_safe_zones = [
        calculate_safe_zone_with_prepositions_test_new(
            frame_width, frame_height, batch_detections[i], pre_positions, subtitle_height, margin
        )[0]  # ✅ Extract only the position name
        for i in range(len(selected_frames))
    ]

    # ✅ Step 4: Determine the Most Used Safe Zone
    combined_safe_zones = batch_safe_zones + list(safe_zone_history)  # Merge with history
    print(combined_safe_zones)
    zone_counts = Counter(combined_safe_zones)  # Count occurrences

    # ✅ Assign the most frequently used zone
    if zone_counts:
        most_common_zones = zone_counts.most_common()  # Get all zones sorted by frequency
        highest_frequency = most_common_zones[0][1]  # Find the highest occurrence count

        # ✅ Get all zones with the highest frequency
        top_zones = [zone for zone, count in most_common_zones if count == highest_frequency]

        # ✅ If there's a tie, choose the last used zone from combined_safe_zones
        final_safe_zone = next((zone for zone in reversed(combined_safe_zones) if zone in top_zones), "bottom")
    else:
        final_safe_zone = "bottom"  # ✅ Default fallback
    print(f"✅ Final Safe Zone: {final_safe_zone}")


    # ✅ Store the final safe zone for future frames
    safe_zone_history.append(final_safe_zone)

    # ✅ Step 5: Apply Safe Zone to All Frames in the Batch
    # return [
    #     cv2.rectangle(frames[i], (final_safe_zone[0], final_safe_zone[1]),
    #                   (final_safe_zone[2], final_safe_zone[3]), (255, 0, 0), 3)

    #     for i in range(len(frames))
    # ]

    # processed_frames = []
    # for i, frame in enumerate(frames):
    #     subtitle_text = subtitles[i]
    #     processed_frame = render_subtitle_multi_new(frame, subtitle_text, final_safe_zone, frame_width, frame_height)
    #     processed_frames.append(processed_frame)

    return final_safe_zone

# %%
import xml.etree.ElementTree as ET

def print_ttml_with_updated_regions(ttml_file_path, subtitle_data):
    """
    Prints the TTML <p> elements with updated regions, removing 'region' if it's None.

    Parameters:
        ttml_file_path (str): Path to the TTML file.
        subtitle_data (list): List of subtitles in the format:
            [{"start": start_time, "end": end_time, "text": text, "region": "region_id"}]
    """

    # ✅ Load TTML File
    tree = ET.parse(ttml_file_path)
    root = tree.getroot()
    ns = {'ttml': 'http://www.w3.org/ns/ttml'}

    # ✅ Find All <p> Elements (Subtitles) and Update Regions
    for p in root.findall('.//ttml:p', ns):
        start_time = convert_ttml_time_to_seconds(p.attrib.get("begin", "0.0s"))
        end_time = convert_ttml_time_to_seconds(p.attrib.get("end", "0.0s"))

        # ✅ Find Matching Subtitle
        matched_subtitle = next((sub for sub in subtitle_data if sub["start"] <= start_time <= sub["end"]), None)

        if matched_subtitle:
            if matched_subtitle["region"] is not None:
                p.attrib["region"] = matched_subtitle["region"]  # ✅ Assign Correct Region
            elif "region" in p.attrib:
                del p.attrib["region"]  # ✅ Remove `region` if it's None

    # ✅ Print Updated TTML Content
    updated_ttml = ET.tostring(root, encoding="utf-8").decode("utf-8")
    print(updated_ttml)  # ✅ Print instead of writing to a file

# %%
import xml.etree.ElementTree as ET
import json

def generate_ttml_with_styling(ttml_file_path, json_data, frame_width, frame_height):
    """
    Ensures the TTML file has <styling> and <layout> sections and updates them with subtitle styles and positions.

    Parameters:
        ttml_file_path (str): Path to the TTML file.
        json_data (dict): JSON data containing subtitle positions.
        frame_width (int): Width of the video frame.
        frame_height (int): Height of the video frame.

    Returns:
        None (Prints updated TTML with styling and layout)
    """

    # ✅ Load TTML File
    tree = ET.parse(ttml_file_path)
    root = tree.getroot()

    # ✅ Define namespace for TTML (ensure correct XML parsing)
    ns = {'ttml': 'http://www.w3.org/ns/ttml'}
    ET.register_namespace("", ns["ttml"])

    # ✅ Find or Create the <head> Element
    head_element = root.find('.//ttml:head', ns)
    if head_element is None:
        head_element = ET.Element("{http://www.w3.org/ns/ttml}head")
        root.insert(0, head_element)  # Insert <head> at the top

    # ✅ Find or Create the <styling> Element (for subtitle styles)
    styling_element = head_element.find('.//ttml:styling', ns)
    if styling_element is None:
        styling_element = ET.Element("{http://www.w3.org/ns/ttml}styling")
        head_element.insert(0, styling_element)  # Insert styling before layout

    styling_element = head_element.find('.//ttml:styling', ns)
    if styling_element is None:
        styling_element = ET.Element("{http://www.w3.org/ns/ttml}styling")
        head_element.append(styling_element)  # Append inside <head>

    # ✅ Remove Any Existing <style> Elements (Always Replacing)
    for style in styling_element.findall('.//ttml:style', ns):
        styling_element.remove(style)

    # ✅ Define and Add the New Style Element
    new_style = ET.Element("{http://www.w3.org/ns/ttml}style", attrib={
        "xml:id": "s0",  # Always standardizing as "s0"
        "tts:color": "white",
        "tts:fontSize": "70%",
        "tts:fontFamily": "sansSerif",
        "tts:backgroundColor": "black",
        "tts:displayAlign": "center",
        "tts:wrapOption": "wrap"
    })
    styling_element.append(new_style)  # ✅ Add New Styling

    # ✅ Find or Create the <layout> Element (for subtitle positions)
    layout_element = head_element.find('.//ttml:layout', ns)
    if layout_element is None:
        layout_element = ET.Element("{http://www.w3.org/ns/ttml}layout")
        head_element.append(layout_element)  # Append layout after styling

    # ✅ Remove ALL existing <region> elements inside <layout>
    for region in list(layout_element):
        layout_element.remove(region)

    # ✅ Insert Subtitle Regions from JSON (Predefined & Dynamic)
    for region_name, region_data in json_data.items():
        x1, y1, x2, y2 = region_data["coordinates"]

        # Convert absolute pixel values to TTML percentages
        origin_x = (x1 / frame_width) * 100
        origin_y = (y1 / frame_height) * 100
        extent_x = ((x2 - x1) / frame_width) * 100
        extent_y = ((y2 - y1) / frame_height) * 100

        # Construct the region XML element
        region_element = ET.Element("{http://www.w3.org/ns/ttml}region", attrib={
            "tts:origin": f"{origin_x:.2f}% {origin_y:.2f}%",
            "tts:extent": f"{extent_x:.2f}% {extent_y:.2f}%",
            "tts:displayAlign": "center",
            "tts:textAlign": "center",
            "xml:id": region_name
        })

        # Add new regions to the layout
        layout_element.append(region_element)

    # ✅ Print Updated TTML with Styling & Layout
    updated_ttml = ET.tostring(root, encoding="utf-8").decode("utf-8")
    print(updated_ttml)

# %%
import xml.etree.ElementTree as ET
import json

def generate_updated_ttml(ttml_file_path, output_ttml_path, json_data, subtitle_data, frame_width, frame_height):
    """
    Generates a new TTML file with updated subtitle styles, layout regions, and assigned regions for subtitles.

    Parameters:
        ttml_file_path (str): Path to the input TTML file.
        output_ttml_path (str): Path to save the updated TTML file.
        json_data (dict): JSON data containing subtitle positions.
        subtitle_data (list): List of subtitles with timestamps and regions.
        frame_width (int): Width of the video frame.
        frame_height (int): Height of the video frame.

    Returns:
        None (Writes updated TTML file to disk)
    """

    # ✅ Load TTML File
    tree = ET.parse(ttml_file_path)
    root = tree.getroot()

    # # ✅ Define Namespace for TTML
    # ns = {'ttml': 'http://www.w3.org/ns/ttml'}
    # ET.register_namespace("", ns["ttml"])

    # # ✅ Find or Create the <head> Element
    # head_element = root.find('.//ttml:head', ns)
    # if head_element is None:
    #     head_element = ET.Element("{http://www.w3.org/ns/ttml}head")
    #     root.insert(0, head_element)  # Insert <head> at the top

    # ✅ Load TTML File
    tree = ET.parse(ttml_file_path)
    root = tree.getroot()

    # ✅ Preserve All Original Root Attributes (Ensuring All Namespaces Remain)
    root_attribs = root.attrib.copy()  # Copy attributes before modification

    # ✅ Extract Namespace (from <tt> root tag)
    namespace_uri = root.tag.split("}")[0].strip("{")  # Extracts URI from "{namespace}tag"
    ns = {"ttml": namespace_uri} if namespace_uri else {}

    # ✅ Restore All Root Attributes (Explicitly Add Missing Namespaces)
    root.attrib.clear()
    root.attrib.update(root_attribs)  # ✅ Restore original attributes

    # ✅ Ensure `xmlns:tts` is Explicitly Set (if missing)
    if "xmlns:tts" not in root.attrib:
        root.set("xmlns:tts", "http://www.w3.org/ns/ttml#styling")  # ✅ Add missing styling namespace

    # ✅ Find or Create the <head> Element (Using Preserved Namespace)
    head_element = root.find(f'.//{{{namespace_uri}}}head', ns)
    if head_element is None:
        head_element = ET.Element(f"{{{namespace_uri}}}head")
        root.insert(0, head_element)  # Insert <head> as the first child

    # ✅ Find or Create the <styling> Element
    styling_element = head_element.find('.//ttml:styling', ns)
    if styling_element is None:
        styling_element = ET.Element("{http://www.w3.org/ns/ttml}styling")
        head_element.insert(0, styling_element)  # Insert before layout

    # ✅ Remove Any Existing <style> Elements (Always Replacing)
    for style in styling_element.findall('.//ttml:style', ns):
        styling_element.remove(style)

    # ✅ Define and Add the New Style Element
    new_style = ET.Element("{http://www.w3.org/ns/ttml}style", attrib={
        "xml:id": "s0",
        "tts:color": "white",
        "tts:fontSize": "70%",
        "tts:fontFamily": "sansSerif",
        "tts:backgroundColor": "black",
        "tts:displayAlign": "center",
        "tts:wrapOption": "wrap"
    })
    styling_element.append(new_style)

    # ✅ Find or Create the <layout> Element
    layout_element = head_element.find('.//ttml:layout', ns)
    if layout_element is None:
        layout_element = ET.Element("{http://www.w3.org/ns/ttml}layout")
        head_element.append(layout_element)

    # ✅ Remove ALL existing <region> elements inside <layout>
    for region in list(layout_element):
        layout_element.remove(region)

    # ✅ Insert Subtitle Regions from JSON
    for region_name, region_data in json_data.items():
        x1, y1, x2, y2 = region_data["coordinates"]

        # Convert absolute pixel values to TTML percentages
        origin_x = (x1 / frame_width) * 100
        origin_y = (y1 / frame_height) * 100
        extent_x = ((x2 - x1) / frame_width) * 100
        extent_y = ((y2 - y1) / frame_height) * 100

        # Construct the region XML element
        region_element = ET.Element("{http://www.w3.org/ns/ttml}region", attrib={
            "tts:origin": f"{origin_x:.2f}% {origin_y:.2f}%",
            "tts:extent": f"{extent_x:.2f}% {extent_y:.2f}%",
            "tts:displayAlign": "center",
            "tts:textAlign": "center",
            "xml:id": region_name
        })

        # Add to <layout>
        layout_element.append(region_element)

    # ✅ Find All <p> Elements (Subtitles) and Update Regions
    for p in root.findall('.//ttml:p', ns):
        start_time = convert_ttml_time_to_seconds(p.attrib.get("begin", "0.0s"))
        end_time = convert_ttml_time_to_seconds(p.attrib.get("end", "0.0s"))

        # ✅ Find Matching Subtitle
        matched_subtitle = next((sub for sub in subtitle_data if sub["start"] <= start_time <= sub["end"]), None)

        if matched_subtitle:
            if matched_subtitle["region"] is not None:
                p.attrib["region"] = matched_subtitle["region"]  # ✅ Assign Correct Region
            elif "region" in p.attrib:
                del p.attrib["region"]  # ✅ Remove `region` if it's None

    # ✅ Save Updated TTML File
    # tree.write(output_ttml_path, encoding="utf-8", xml_declaration=True)
    # print(f"✅ Updated TTML file saved: {output_ttml_path}")
    updated_ttml = ET.tostring(root, encoding="utf-8").decode("utf-8")
    print(updated_ttml)

# %% [markdown]
# ## Testing the Code

# %% [markdown]
# ### Integrate with srt file and video fps

# %%
# !pip install pysrt
# Out:
# Collecting pysrt
#   Downloading pysrt-1.1.2.tar.gz (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.4/104.4 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: chardet in /usr/local/lib/python3.11/dist-packages (from pysrt) (5.2.0)
# Building wheels for collected packages: pysrt
#   Building wheel for pysrt (setup.py) ... done
#   Created wheel for pysrt: filename=pysrt-1.1.2-py3-none-any.whl size=13443 sha256=8863bbe87bf632466fe71e3aa1001f5252a22c5f7f45377f4cbd6ee8fc3aed1a
#   Stored in directory: /root/.cache/pip/wheels/2d/b2/df/ea10959920533975b4a74a25a35e6d79655b63f3006611a99f
# Successfully built pysrt
# Installing collected packages: pysrt
# Successfully installed pysrt-1.1.2

# %%
import pysrt
from collections import defaultdict

def parse_srt_file(srt_file):
    """
    Reads and parses an SRT file, pre-indexing subtitles for fast lookup.

    Parameters:
        srt_file (str): Path to the .srt file.

    Returns:
        dict: A dictionary where keys are integer timestamps (seconds),
              and values are subtitle texts.
    """
    subs = pysrt.open(srt_file)
    subtitle_dict = defaultdict(lambda: None)  # Default to None for missing frames

    for sub in subs:
        start_time = int(sub.start.minutes * 60 + sub.start.seconds)  # Round to nearest second
        end_time = int(sub.end.minutes * 60 + sub.end.seconds)
        subtitle_text = sub.text.replace("\n", " ")  # Convert newlines to spaces

        # ✅ Store subtitles for all frames in the time range
        for t in range(start_time, end_time + 1):
            subtitle_dict[t] = subtitle_text

    return subtitle_dict  # Faster lookups using a dictionary

# %%
def get_subtitles_for_frames(frame_times, subtitle_data):
    """
    Retrieves subtitle texts for a batch of frame timestamps.

    Parameters:
        frame_times (list): List of timestamps (in seconds).
        subtitle_data (list): List of subtitles in the format:
            [{"start": start_time, "end": end_time, "text": text, "region": region}, ...]

    Returns:
        list: List of subtitle texts corresponding to each frame timestamp.
    """
    frame_subtitles = []

    for time in frame_times:
        subtitle_text = ""  # Default to empty string

        for subtitle in subtitle_data:
            if subtitle["start"] <= time <= subtitle["end"]:
                subtitle_text = subtitle["text"].replace("\n", " ")  # Remove newlines
                break  # Stop once we find a match

        frame_subtitles.append(subtitle_text)

    return frame_subtitles

# %%
def get_video_fps(video_path):
    """Extracts FPS from a video using FFmpeg."""
    cmd = ["ffmpeg", "-i", video_path]

    # ✅ Use stdout and stderr explicitly
    result = subprocess.run(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # ✅ Parse FPS from FFmpeg output
    for line in result.stderr.split("\n"):
        if "Stream" in line and "Video" in line and "fps" in line:
            fps_value = float(line.split("fps")[0].strip().split()[-1])  # Extract FPS
            return fps_value

    return 30  # Default to 30 FPS if not found

# %%
def should_process_frame(frame_time, subtitle_timestamps, fps, tolerance=0.01):
    """
    Checks if a frame's timestamp falls within any subtitle duration, with a small tolerance.

    Returns True if the frame should be processed, False otherwise.
    """
    frame_tolerance = 1 / fps  # The duration of a single frame in seconds
    adjusted_tolerance = min(tolerance, 2 * frame_tolerance)  # Limit to 2 frames

    result = any((start - adjusted_tolerance) <= frame_time <= (end + adjusted_tolerance)
                 for start, end in subtitle_timestamps)

    # print(f"Frame Time: {frame_time:.3f}s | Process: {result}")  # ✅ Print Result
    return result

# %%
## combined srt and ttml timestamp

import pysrt
import xml.etree.ElementTree as ET
import re

def get_subtitle_timestamps(subtitle_file, file_type="auto"):
    """
    Extracts subtitle timestamps from an SRT or TTML file.

    Parameters:
        subtitle_file (str): Path to the subtitle file.
        file_type (str): "srt" for SRT, "ttml" for TTML, or "auto" to detect from extension.

    Returns:
        list of tuples: Each tuple contains (start_time, end_time) in seconds.
    """
    # Auto-detect file type
    if file_type == "auto":
        if subtitle_file.endswith(".srt"):
            file_type = "srt"
        elif subtitle_file.endswith(".ttml") or subtitle_file.endswith(".xml"):
            file_type = "ttml"
        else:
            raise ValueError("Unsupported subtitle file format. Use 'srt' or 'ttml'.")

    # Process SRT
    if file_type == "srt":
        return get_srt_timestamps(subtitle_file)

    # Process TTML
    elif file_type == "ttml":
        return get_ttml_timestamps(subtitle_file)

    else:
        raise ValueError("Invalid file type specified. Use 'srt' or 'ttml'.")

def get_srt_timestamps(srt_file):
    """Extracts subtitle timestamps from an SRT file."""
    subs = pysrt.open(srt_file)
    subtitle_timestamps = []

    for sub in subs:
        start_time = sub.start.hours * 3600 + sub.start.minutes * 60 + sub.start.seconds + sub.start.milliseconds / 1000
        end_time = sub.end.hours * 3600 + sub.end.minutes * 60 + sub.end.seconds + sub.end.milliseconds / 1000
        subtitle_timestamps.append((start_time, end_time))

    return subtitle_timestamps

def get_ttml_timestamps(ttml_file):
    """Extracts subtitle timestamps from a TTML file."""
    tree = ET.parse(ttml_file)
    root = tree.getroot()
    ns = {'ttml': 'http://www.w3.org/ns/ttml'}

    subtitle_timestamps = []

    for p in root.findall('.//ttml:p', ns):
        start_time = p.attrib.get("begin", "0.0s")
        end_time = p.attrib.get("end", "0.0s")

        start_seconds = convert_ttml_time_to_seconds(start_time)
        end_seconds = convert_ttml_time_to_seconds(end_time)

        subtitle_timestamps.append((start_seconds, end_seconds))

    return subtitle_timestamps

# def convert_ttml_time_to_seconds(ttml_time):
#     """
#     Converts TTML time format (HH:MM:SS.mmm or MM:SS.mmm or SS.mmm or SS.mmm's') to seconds.

#     Parameters:
#         ttml_time (str): TTML-formatted time.

#     Returns:
#         float: Time in seconds.
#     """
#     ttml_time = ttml_time.rstrip('s')  # Remove trailing 's' if present
#     parts = ttml_time.split(":")

#     if len(parts) == 3:  # HH:MM:SS.mmm
#         hours, minutes, seconds = map(float, parts)
#     elif len(parts) == 2:  # MM:SS.mmm
#         hours, minutes, seconds = 0, *map(float, parts)
#     else:  # SS.mmm
#         hours, minutes, seconds = 0, 0, float(parts[0])

#     return hours * 3600 + minutes * 60 + seconds

def convert_ttml_time_to_seconds(ttml_time):
    """
    Converts TTML time format (HH:MM:SS.mmm, MM:SS.mmm, SS.mmm, or SS,mmm) to seconds.

    Parameters:
        ttml_time (str): TTML-formatted time.

    Returns:
        float: Time in seconds (with millisecond precision).
    """

    # ✅ Remove trailing 's' if present and replace ',' with '.'
    ttml_time = ttml_time.rstrip('s').replace(',', '.')

    # ✅ Use regex to extract time components
    match = re.match(r"(?:(\d+):)?(?:(\d+):)?(\d+)(?:\.(\d+))?", ttml_time)

    if not match:
        raise ValueError(f"Invalid TTML time format: {ttml_time}")

    # ✅ Extract components safely
    hours = int(match.group(1)) if match.group(1) else 0
    minutes = int(match.group(2)) if match.group(2) else 0
    seconds = int(match.group(3)) if match.group(3) else 0
    milliseconds = int(match.group(4)) if match.group(4) else 0

    return hours * 3600 + minutes * 60 + seconds + milliseconds / 1000.0

# %%
import xml.etree.ElementTree as ET
import pysrt
import os

def parse_subtitle_file(file_path):
    """
    Parses either an SRT or TTML subtitle file and extracts subtitles.

    Parameters:
        file_path (str): Path to the subtitle file.

    Returns:
        list: List of subtitles in the format:
            [
                {"start": start_time, "end": end_time, "text": "subtitle text", "region": "region_id"}
            ]
    """
    extension = os.path.splitext(file_path)[-1].lower()
    subtitle_data = []

    if extension == ".srt":
        subs = pysrt.open(file_path)
        for sub in subs:
            start_time = (
                sub.start.hours * 3600 + sub.start.minutes * 60 + sub.start.seconds + sub.start.milliseconds / 1000
            )
            end_time = (
                sub.end.hours * 3600 + sub.end.minutes * 60 + sub.end.seconds + sub.end.milliseconds / 1000
            )
            text = sub.text.replace("\n", " ")  # Convert newlines to spaces

            subtitle_data.append({
                "start": start_time,
                "end": end_time,
                "text": text,
                "region": None  # SRT doesn't support regions
            })

    elif extension == ".ttml":
        # ✅ Register TTML Namespaces
        ET.register_namespace('', "http://www.w3.org/ns/ttml")  # Default TTML namespace
        ET.register_namespace('ttp', "http://www.w3.org/ns/ttml#parameter")
        ET.register_namespace('tts', "http://www.w3.org/ns/ttml#styling")
        ET.register_namespace('ttm', "http://www.w3.org/ns/ttml#metadata")

        # ✅ Parse TTML File
        tree = ET.parse(file_path)
        root = tree.getroot()
        ns = {'ttml': 'http://www.w3.org/ns/ttml'}

        # ✅ Extract Subtitle Data
        for p in root.findall('.//ttml:p', ns):
            start_time = convert_ttml_time_to_seconds(p.attrib.get("begin", "0.0s"))
            end_time = convert_ttml_time_to_seconds(p.attrib.get("end", "0.0s"))
            text = " ".join(p.itertext()).strip()
            region = p.attrib.get("region", None)

            subtitle_data.append({
                "start": start_time,
                "end": end_time,
                "text": text,
                "region": region
            })

    else:
        raise ValueError("Unsupported subtitle format. Only SRT and TTML are supported.")

    return subtitle_data

# %%
## current main test

import os
import cv2
import subprocess

# ✅ Define file paths in /content/
video_input_path = "/content/optimal_subtitle_copied/test_video_4.mp4"
# final_video_path = "/content/optimal_subtitle_copied/test_video_with_audio.mp4"
file_path = "/content/optimal_subtitle_copied/TTML_file/test_long_video_48.ttml"
output_path = "/content/output.ttml"
# json_path = "/content/optimal_subtitle_copied/subtitle_positions_ttml.json"

subtitle_data_updated = []

# ✅ Extract FPS dynamically
fps = get_video_fps(video_input_path)
print(f"✅ Corrected FPS: {fps}")

# ✅ Load Pre-indexed Subtitles
subtitle_data = parse_subtitle_file(file_path)

# ✅ Load Subtitle Timestamps
subtitle_timestamps = get_subtitle_timestamps(file_path)

# ✅ Open Video File
cap = cv2.VideoCapture(video_input_path)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
print(f"Frame Width: {frame_width}, Frame Height: {frame_height}")

# ✅ Initialize Video Writer
# fourcc = cv2.VideoWriter_fourcc(*"mp4v")
# out = cv2.VideoWriter(final_video_path, fourcc, fps, (frame_width, frame_height))

# ✅ Process Video Based on Subtitle Timeframes
frame_buffer = []
timestamp_buffer = []
subtitle_index = 0  # Track current subtitle
frame_number = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break  # Exit if no more frames

    frame_time = frame_number / fps  # Convert frame number to timestamp

    # ✅ Ensure we have a valid subtitle to match
    if subtitle_index < len(subtitle_data):
        current_subtitle = subtitle_data[subtitle_index]
        current_start = current_subtitle["start"]
        current_end = current_subtitle["end"]
        subtitle_text = current_subtitle["text"]

        # ✅ Collect frames only within the current subtitle's timestamp range
        if current_start <= frame_time <= current_end:
            frame_buffer.append(frame)
            timestamp_buffer.append(frame_time)

        # ✅ When the last frame of the subtitle is reached, process the batch
        if frame_time > current_end:
            if frame_buffer:  # Ensure we have frames to process
                subtitles = [current_subtitle]  # Use only the current subtitle's data

                processed_frames = process_frames_batch_3fps_processed(frame_buffer, subtitles)
                current_subtitle["region"] = processed_frames
                # print(processed_frames)

                # ✅ Append processed subtitle data dynamically
                # subtitle_data.append({
                #     "start": current_start,
                #     "end": current_end,
                #     "text": subtitle_text,
                #     "region": processed_frames  # ✅ Dynamically determined region
                # })

                # ✅ Write processed frames to the output video
                # for processed_frame in processed_frames:
                #     print(processed_frame)

                # ✅ Clear buffers and move to the next subtitle
                frame_buffer.clear()
                timestamp_buffer.clear()
                subtitle_index += 1

    frame_number += 1

# ✅ Process remaining frames if any subtitles are left
if frame_buffer:
    subtitles = [subtitle_data[subtitle_index]]  # Process last remaining batch
    processed_frames = process_frames_batch_3fps_processed(frame_buffer, subtitles)
    print(processed_frames)

cap.release()

layout = get_used_safe_zones()
generate_updated_ttml(file_path, output_path, layout, subtitle_data, frame_width, frame_height)
# print_ttml_with_updated_regions(file_path, subtitle_data)

# layout = get_used_safe_zones()
# generate_ttml_with_styling(file_path, layout, frame_width, frame_height)
# out.release()
# print(f"✅ Video processing completed: {final_video_path}")
# Out:
# Streaming output truncated to the last 5000 lines.
# 35: 384x640 1 face, 3 logos, 2 news-tickers, 3 texts, 32.6ms
# 36: 384x640 1 face, 3 logos, 2 news-tickers, 3 texts, 32.6ms
# 37: 384x640 1 face, 3 logos, 3 news-tickers, 2 texts, 32.6ms
# 38: 384x640 1 face, 2 logos, 2 news-tickers, 2 texts, 32.6ms
# 39: 384x640 1 face, 3 logos, 4 news-tickers, 2 texts, 32.6ms
# 40: 384x640 1 face, 3 logos, 4 news-tickers, 2 texts, 32.6ms
# 41: 384x640 1 face, 3 logos, 4 news-tickers, 2 texts, 32.6ms
# 42: 384x640 1 face, 3 logos, 3 news-tickers, 2 texts, 32.6ms
# 43: 384x640 1 face, 3 logos, 3 news-tickers, 2 texts, 32.6ms
# 44: 384x640 1 face, 4 logos, 3 news-tickers, 2 texts, 32.6ms
# 45: 384x640 1 face, 3 logos, 1 news-ticker, 2 texts, 32.6ms
# 46: 384x640 1 face, 1 logo, 1 news-ticker, 4 texts, 32.6ms
# 47: 384x640 1 logo, 1 news-ticker, 4 texts, 32.6ms
# Speed: 1.7ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (48, 3, 384, 640)
# ['shifted_top', 'shifted_top', 'shifted_middle3', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'shifted_middle3', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_middle3', 'shifted_top', 'shifted_middle3', 'shifted_top', 'middle2', 'middle2', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3']
# ✅ Final Safe Zone: middle2
#
# 0: 384x640 1 logo, 2 news-tickers, 4 texts, 3.2ms
# 1: 384x640 1 logo, 1 news-ticker, 4 texts, 3.2ms
# 2: 384x640 1 logo, 1 news-ticker, 4 texts, 3.2ms
# 3: 384x640 1 logo, 2 news-tickers, 4 texts, 3.2ms
# 4: 384x640 1 logo, 2 news-tickers, 5 texts, 3.2ms
# 5: 384x640 1 logo, 1 news-ticker, 3 texts, 3.2ms
# 6: 384x640 1 face, 1 logo, 1 news-ticker, 1 sidebar, 3 texts, 3.2ms
# 7: 384x640 1 face, 1 logo, 1 news-ticker, 1 sidebar, 3 texts, 3.2ms
# 8: 384x640 1 face, 1 logo, 1 news-ticker, 3 texts, 3.2ms
# Speed: 2.3ms preprocess, 3.2ms inference, 1.3ms postprocess per image at shape (9, 3, 384, 640)
# ['middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'middle2']
# ✅ Final Safe Zone: middle2
#
# 0: 384x640 1 face, 1 logo, 2 news-tickers, 3 texts, 2.5ms
# 1: 384x640 1 face, 1 logo, 1 news-ticker, 3 texts, 2.5ms
# 2: 384x640 2 faces, 1 logo, 1 news-ticker, 3 texts, 2.5ms
# 3: 384x640 2 faces, 1 logo, 1 news-ticker, 3 texts, 2.5ms
# 4: 384x640 2 faces, 1 logo, 2 news-tickers, 3 texts, 2.5ms
# 5: 384x640 2 faces, 1 logo, 1 news-ticker, 3 texts, 2.5ms
# 6: 384x640 2 faces, 1 logo, 1 news-ticker, 1 sidebar, 3 texts, 2.5ms
# Speed: 1.6ms preprocess, 2.5ms inference, 0.8ms postprocess per image at shape (7, 3, 384, 640)
# ['middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'middle2', 'middle2']
# ✅ Final Safe Zone: middle2
#
# 0: 384x640 2 faces, 1 logo, 1 news-ticker, 1 sidebar, 3 texts, 2.7ms
# 1: 384x640 1 face, 1 logo, 1 news-ticker, 1 sidebar, 3 texts, 2.7ms
# 2: 384x640 2 faces, 1 logo, 1 news-ticker, 1 sidebar, 3 texts, 2.7ms
# 3: 384x640 2 faces, 1 logo, 1 news-ticker, 1 sidebar, 3 texts, 2.7ms
# 4: 384x640 1 face, 1 logo, 1 news-ticker, 3 texts, 2.7ms
# 5: 384x640 1 face, 3 logos, 3 news-tickers, 2 texts, 2.7ms
# 6: 384x640 1 face, 4 logos, 1 news-ticker, 2 texts, 2.7ms
# 7: 384x640 2 faces, 4 logos, 2 news-tickers, 1 sidebar, 2 texts, 2.7ms
# 8: 384x640 2 faces, 4 logos, 1 news-ticker, 1 sidebar, 2 texts, 2.7ms
# 9: 384x640 2 faces, 4 logos, 1 news-ticker, 2 texts, 2.7ms
# Speed: 1.7ms preprocess, 2.7ms inference, 1.0ms postprocess per image at shape (10, 3, 384, 640)
# ['middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'middle2', 'middle2', 'middle2']
# ✅ Final Safe Zone: middle2
#
# 0: 384x640 2 faces, 4 logos, 1 news-ticker, 2 texts, 2.6ms
# 1: 384x640 1 face, 3 logos, 1 news-ticker, 1 sidebar, 2 texts, 2.6ms
# 2: 384x640 1 face, 3 logos, 2 news-tickers, 1 sidebar, 4 texts, 2.6ms
# 3: 384x640 1 face, 3 logos, 1 news-ticker, 3 texts, 2.6ms
# 4: 384x640 1 face, 3 logos, 1 news-ticker, 4 texts, 2.6ms
# 5: 384x640 1 face, 3 logos, 3 news-tickers, 3 texts, 2.6ms
# Speed: 1.7ms preprocess, 2.6ms inference, 0.9ms postprocess per image at shape (6, 3, 384, 640)
# ['fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'middle2', 'middle2', 'middle2', 'middle2']
# ✅ Final Safe Zone: shifted_middle3
#
# 0: 384x640 1 face, 3 logos, 2 news-tickers, 4 texts, 2.4ms
# 1: 384x640 1 face, 3 logos, 1 news-ticker, 4 texts, 2.4ms
# 2: 384x640 1 face, 3 logos, 2 news-tickers, 3 texts, 2.4ms
# 3: 384x640 1 face, 3 logos, 2 news-tickers, 3 texts, 2.4ms
# 4: 384x640 1 face, 4 logos, 2 news-tickers, 2 texts, 2.4ms
# 5: 384x640 1 face, 4 logos, 2 news-tickers, 2 texts, 2.4ms
# 6: 384x640 1 face, 4 logos, 4 news-tickers, 2 texts, 2.4ms
# 7: 384x640 1 face, 1 logo, 1 news-ticker, 5 texts, 2.4ms
# 8: 384x640 1 face, 1 logo, 1 news-ticker, 5 texts, 2.4ms
# 9: 384x640 1 face, 1 logo, 1 news-ticker, 5 texts, 2.4ms
# Speed: 1.6ms preprocess, 2.4ms inference, 0.8ms postprocess per image at shape (10, 3, 384, 640)
# ['fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'middle2', 'middle2', 'middle2', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'middle2', 'middle2', 'middle2', 'middle2', 'shifted_middle3']
# ✅ Final Safe Zone: middle2
#
# 0: 384x640 1 face, 1 logo, 1 news-ticker, 5 texts, 3.0ms
# 1: 384x640 1 face, 1 logo, 1 news-ticker, 5 texts, 3.0ms
# 2: 384x640 1 logo, 1 news-ticker, 5 texts, 3.0ms
# 3: 384x640 1 logo, 1 news-ticker, 4 texts, 3.0ms
# 4: 384x640 1 logo, 1 news-ticker, 4 texts, 3.0ms
# 5: 384x640 1 face, 1 logo, 1 news-ticker, 4 texts, 3.0ms
# 6: 384x640 1 face, 1 logo, 2 news-tickers, 4 texts, 3.0ms
# Speed: 1.8ms preprocess, 3.0ms inference, 0.9ms postprocess per image at shape (7, 3, 384, 640)
# ['middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'middle2', 'middle2', 'middle2', 'middle2', 'shifted_middle3', 'middle2']
# ✅ Final Safe Zone: middle2
#
# 0: 384x640 1 face, 1 logo, 2 news-tickers, 4 texts, 3.9ms
# 1: 384x640 2 faces, 1 logo, 2 news-tickers, 3 texts, 3.9ms
# 2: 384x640 1 face, 1 logo, 2 news-tickers, 3 texts, 3.9ms
# 3: 384x640 1 face, 1 logo, 2 news-tickers, 3 texts, 3.9ms
# 4: 384x640 1 face, 1 logo, 1 news-ticker, 3 texts, 3.9ms
# Speed: 1.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (5, 3, 384, 640)
# ['middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'middle2', 'middle2', 'middle2', 'middle2', 'shifted_middle3', 'middle2', 'middle2']
# ✅ Final Safe Zone: middle2
#
# 0: 384x640 1 face, 1 logo, 1 news-ticker, 3 texts, 3.7ms
# 1: 384x640 1 face, 1 logo, 2 news-tickers, 3 texts, 3.7ms
# 2: 384x640 1 face, 1 logo, 2 news-tickers, 3 texts, 3.7ms
# 3: 384x640 1 face, 1 logo, 1 news-ticker, 3 texts, 3.7ms
# 4: 384x640 1 face, 1 logo, 2 news-tickers, 3 texts, 3.7ms
# 5: 384x640 2 faces, 3 logos, 3 news-tickers, 2 texts, 3.7ms
# 6: 384x640 2 faces, 4 logos, 5 news-tickers, 2 texts, 3.7ms
# 7: 384x640 2 faces, 4 logos, 2 news-tickers, 2 texts, 3.7ms
# 8: 384x640 2 faces, 4 logos, 2 news-tickers, 1 sidebar, 2 texts, 3.7ms
# 9: 384x640 2 faces, 4 logos, 1 news-ticker, 2 texts, 3.7ms
# 10: 384x640 2 faces, 4 logos, 2 news-tickers, 1 sidebar, 3 texts, 3.7ms
# 11: 384x640 2 faces, 4 logos, 4 news-tickers, 1 sidebar, 3 texts, 3.7ms
# 12: 384x640 2 faces, 3 logos, 2 news-tickers, 1 sidebar, 2 texts, 3.7ms
# 13: 384x640 2 faces, 4 logos, 2 news-tickers, 1 sidebar, 2 texts, 3.7ms
# 14: 384x640 2 faces, 4 logos, 2 news-tickers, 2 texts, 3.7ms
# 15: 384x640 2 faces, 4 logos, 3 news-tickers, 2 texts, 3.7ms
# 16: 384x640 1 face, 5 logos, 2 news-tickers, 1 sidebar, 2 texts, 3.7ms
# 17: 384x640 1 face, 5 logos, 4 news-tickers, 1 sidebar, 3 texts, 3.7ms
# 18: 384x640 1 face, 4 logos, 4 news-tickers, 3 texts, 3.7ms
# 19: 384x640 1 face, 5 logos, 3 news-tickers, 2 texts, 3.7ms
# 20: 384x640 1 face, 6 logos, 3 news-tickers, 3 texts, 3.7ms
# Speed: 1.6ms preprocess, 3.7ms inference, 0.7ms postprocess per image at shape (21, 3, 384, 640)
# ['middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'shifted_middle3', 'shifted_middle3', 'middle2', 'middle2', 'middle2', 'middle2', 'shifted_middle3', 'middle2', 'middle2', 'middle2']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 2 faces, 3 logos, 1 news-ticker, 2 texts, 4.2ms
# 1: 384x640 1 face, 4 logos, 4 news-tickers, 2 texts, 4.2ms
# 2: 384x640 2 faces, 3 logos, 4 news-tickers, 2 texts, 4.2ms
# 3: 384x640 1 face, 3 logos, 4 news-tickers, 2 texts, 4.2ms
# 4: 384x640 1 face, 3 logos, 2 news-tickers, 2 texts, 4.2ms
# 5: 384x640 2 faces, 3 logos, 1 news-ticker, 2 texts, 4.2ms
# Speed: 1.8ms preprocess, 4.2ms inference, 0.9ms postprocess per image at shape (6, 3, 384, 640)
# ['fallback_bottom', 'shifted_top', 'fallback_bottom', 'shifted_top', 'shifted_top', 'fallback_bottom', 'shifted_middle3', 'middle2', 'middle2', 'middle2', 'middle2', 'shifted_middle3', 'middle2', 'middle2', 'middle2', 'fallback_bottom']
# ✅ Final Safe Zone: middle2
#
# 0: 384x640 2 faces, 3 logos, 5 news-tickers, 2 texts, 3.7ms
# 1: 384x640 2 faces, 3 logos, 3 news-tickers, 2 texts, 3.7ms
# 2: 384x640 2 faces, 3 logos, 2 news-tickers, 2 texts, 3.7ms
# 3: 384x640 2 faces, 3 logos, 4 news-tickers, 2 texts, 3.7ms
# 4: 384x640 2 faces, 3 logos, 2 news-tickers, 2 texts, 3.7ms
# 5: 384x640 2 faces, 3 logos, 3 news-tickers, 2 texts, 3.7ms
# 6: 384x640 2 faces, 3 logos, 3 news-tickers, 2 texts, 3.7ms
# 7: 384x640 2 faces, 3 logos, 2 news-tickers, 2 texts, 3.7ms
# 8: 384x640 2 faces, 3 logos, 1 news-ticker, 2 texts, 3.7ms
# Speed: 1.7ms preprocess, 3.7ms inference, 0.8ms postprocess per image at shape (9, 3, 384, 640)
# ['fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'shifted_middle3', 'fallback_bottom', 'shifted_middle3', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'middle2', 'middle2', 'middle2', 'middle2', 'shifted_middle3', 'middle2', 'middle2', 'middle2', 'fallback_bottom', 'middle2']
# ✅ Final Safe Zone: middle2
#
# 0: 384x640 2 faces, 3 logos, 1 news-ticker, 2 texts, 6.9ms
# 1: 384x640 2 faces, 3 logos, 4 news-tickers, 2 texts, 6.9ms
# 2: 384x640 2 faces, 3 logos, 3 news-tickers, 1 sidebar, 1 text, 6.9ms
# Speed: 2.3ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (3, 3, 384, 640)
# ['fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'middle2', 'middle2', 'middle2', 'shifted_middle3', 'middle2', 'middle2', 'middle2', 'fallback_bottom', 'middle2', 'middle2']
# ✅ Final Safe Zone: middle2
#
# 0: 384x640 2 faces, 4 logos, 4 news-tickers, 1 sidebar, 1 text, 3.8ms
# 1: 384x640 3 faces, 3 logos, 4 news-tickers, 1 text, 3.8ms
# 2: 384x640 3 faces, 3 logos, 4 news-tickers, 1 text, 3.8ms
# 3: 384x640 3 faces, 3 logos, 4 news-tickers, 2 texts, 3.8ms
# 4: 384x640 3 faces, 3 logos, 3 news-tickers, 2 texts, 3.8ms
# 5: 384x640 3 faces, 3 logos, 4 news-tickers, 1 sidebar, 2 texts, 3.8ms
# 6: 384x640 3 faces, 3 logos, 2 news-tickers, 1 text, 3.8ms
# 7: 384x640 3 faces, 3 logos, 4 news-tickers, 1 sidebar, 1 text, 3.8ms
# 8: 384x640 3 faces, 3 logos, 3 news-tickers, 1 sidebar, 1 text, 3.8ms
# Speed: 1.8ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (9, 3, 384, 640)
# ['fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'middle2', 'middle2', 'shifted_middle3', 'middle2', 'middle2', 'middle2', 'fallback_bottom', 'middle2', 'middle2', 'middle2']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 2 faces, 3 logos, 3 news-tickers, 1 sidebar, 1 text, 4.4ms
# 1: 384x640 2 faces, 4 logos, 1 news-ticker, 1 sidebar, 1 text, 4.4ms
# 2: 384x640 1 face, 3 logos, 2 news-tickers, 1 text, 4.4ms
# 3: 384x640 2 faces, 3 logos, 2 news-tickers, 1 sidebar, 1 text, 4.4ms
# Speed: 1.7ms preprocess, 4.4ms inference, 0.9ms postprocess per image at shape (4, 3, 384, 640)
# ['fallback_bottom', 'fallback_bottom', 'shifted_middle3', 'fallback_bottom', 'middle2', 'shifted_middle3', 'middle2', 'middle2', 'middle2', 'fallback_bottom', 'middle2', 'middle2', 'middle2', 'fallback_bottom']
# ✅ Final Safe Zone: middle2
#
# 0: 384x640 2 faces, 3 logos, 2 news-tickers, 1 sidebar, 1 text, 3.8ms
# 1: 384x640 2 faces, 3 logos, 2 news-tickers, 1 sidebar, 1 text, 3.8ms
# 2: 384x640 2 faces, 3 logos, 2 news-tickers, 1 sidebar, 1 text, 3.8ms
# 3: 384x640 2 faces, 3 logos, 1 news-ticker, 1 sidebar, 1 text, 3.8ms
# 4: 384x640 2 faces, 3 logos, 2 news-tickers, 1 sidebar, 1 text, 3.8ms
# 5: 384x640 1 face, 3 logos, 2 news-tickers, 1 sidebar, 1 text, 3.8ms
# 6: 384x640 1 face, 3 logos, 1 news-ticker, 1 sidebar, 1 text, 3.8ms
# 7: 384x640 1 face, 3 logos, 2 news-tickers, 1 sidebar, 1 text, 3.8ms
# Speed: 1.6ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (8, 3, 384, 640)
# ['fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_middle3', 'middle2', 'middle2', 'middle2', 'fallback_bottom', 'middle2', 'middle2', 'middle2', 'fallback_bottom', 'middle2']
# ✅ Final Safe Zone: middle2
#
# 0: 384x640 2 faces, 3 logos, 2 news-tickers, 1 sidebar, 3 texts, 4.0ms
# 1: 384x640 2 faces, 3 logos, 1 news-ticker, 3 texts, 4.0ms
# 2: 384x640 2 faces, 3 logos, 2 news-tickers, 2 texts, 4.0ms
# 3: 384x640 2 faces, 3 logos, 1 news-ticker, 2 texts, 4.0ms
# 4: 384x640 2 faces, 3 logos, 2 news-tickers, 2 texts, 4.0ms
# 5: 384x640 2 faces, 3 logos, 2 news-tickers, 2 texts, 4.0ms
# 6: 384x640 2 faces, 3 logos, 1 news-ticker, 1 text, 4.0ms
# Speed: 1.6ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (7, 3, 384, 640)
# ['shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'middle2', 'middle2', 'middle2', 'fallback_bottom', 'middle2', 'middle2', 'middle2', 'fallback_bottom', 'middle2', 'middle2']
# ✅ Final Safe Zone: middle2
#
# 0: 384x640 2 faces, 3 logos, 1 news-ticker, 2 texts, 3.6ms
# 1: 384x640 2 faces, 3 logos, 1 news-ticker, 2 texts, 3.6ms
# 2: 384x640 1 face, 3 logos, 1 news-ticker, 2 texts, 3.6ms
# 3: 384x640 1 face, 3 logos, 1 news-ticker, 2 texts, 3.6ms
# 4: 384x640 2 faces, 3 logos, 1 news-ticker, 2 texts, 3.6ms
# 5: 384x640 2 faces, 3 logos, 1 news-ticker, 2 texts, 3.6ms
# 6: 384x640 2 faces, 3 logos, 1 news-ticker, 2 texts, 3.6ms
# 7: 384x640 2 faces, 3 logos, 1 news-ticker, 2 texts, 3.6ms
# 8: 384x640 2 faces, 3 logos, 1 news-ticker, 2 texts, 3.6ms
# 9: 384x640 2 faces, 3 logos, 1 news-ticker, 2 texts, 3.6ms
# Speed: 1.6ms preprocess, 3.6ms inference, 0.8ms postprocess per image at shape (10, 3, 384, 640)
# ['shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'middle2', 'middle2', 'fallback_bottom', 'middle2', 'middle2', 'middle2', 'fallback_bottom', 'middle2', 'middle2', 'middle2']
# ✅ Final Safe Zone: shifted_middle3
#
# 0: 384x640 2 faces, 3 logos, 1 news-ticker, 2 texts, 4.6ms
# 1: 384x640 2 faces, 3 logos, 1 news-ticker, 2 texts, 4.6ms
# 2: 384x640 2 faces, 3 logos, 1 news-ticker, 2 texts, 4.6ms
# 3: 384x640 2 faces, 3 logos, 1 news-ticker, 2 texts, 4.6ms
# 4: 384x640 2 faces, 3 logos, 1 news-ticker, 1 text, 4.6ms
# 5: 384x640 2 faces, 3 logos, 1 news-ticker, 1 text, 4.6ms
# Speed: 1.7ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (6, 3, 384, 640)
# ['shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'middle2', 'fallback_bottom', 'middle2', 'middle2', 'middle2', 'fallback_bottom', 'middle2', 'middle2', 'middle2', 'shifted_middle3']
# ✅ Final Safe Zone: shifted_middle3
#
# 0: 384x640 2 faces, 3 logos, 1 news-ticker, 1 text, 3.7ms
# 1: 384x640 2 faces, 4 logos, 2 news-tickers, 1 sidebar, 1 text, 3.7ms
# 2: 384x640 2 faces, 3 logos, 2 news-tickers, 1 text, 3.7ms
# 3: 384x640 2 faces, 3 logos, 1 news-ticker, 1 sidebar, 1 text, 3.7ms
# 4: 384x640 2 faces, 3 logos, 1 news-ticker, 1 sidebar, 1 text, 3.7ms
# 5: 384x640 2 faces, 4 logos, 1 news-ticker, 1 text, 3.7ms
# 6: 384x640 2 faces, 3 logos, 2 news-tickers, 1 text, 3.7ms
# 7: 384x640 1 face, 4 logos, 1 news-ticker, 1 sidebar, 1 text, 3.7ms
# 8: 384x640 2 faces, 3 logos, 1 news-ticker, 1 sidebar, 1 text, 3.7ms
# 9: 384x640 2 faces, 4 logos, 1 news-ticker, 1 sidebar, 1 text, 3.7ms
# 10: 384x640 2 faces, 4 logos, 1 news-ticker, 1 text, 3.7ms
# 11: 384x640 1 face, 4 logos, 1 news-ticker, 1 sidebar, 1 text, 3.7ms
# 12: 384x640 2 faces, 4 logos, 1 news-ticker, 1 text, 3.7ms
# 13: 384x640 2 faces, 3 logos, 1 news-ticker, 1 text, 3.7ms
# 14: 384x640 2 faces, 3 logos, 1 news-ticker, 1 text, 3.7ms
# 15: 384x640 2 faces, 3 logos, 1 news-ticker, 1 sidebar, 1 text, 3.7ms
# Speed: 1.6ms preprocess, 3.7ms inference, 0.7ms postprocess per image at shape (16, 3, 384, 640)
# ['shifted_middle3', 'fallback_bottom', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'shifted_middle3', 'shifted_middle3', 'shifted_top', 'fallback_bottom', 'fallback_bottom', 'shifted_middle3', 'shifted_top', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'middle2', 'middle2', 'middle2', 'fallback_bottom', 'middle2', 'middle2', 'middle2', 'shifted_middle3', 'shifted_middle3']
# ✅ Final Safe Zone: shifted_middle3
#
# 0: 384x640 1 face, 4 logos, 3 news-tickers, 3 texts, 4.1ms
# 1: 384x640 1 face, 4 logos, 3 news-tickers, 3 texts, 4.1ms
# 2: 384x640 1 face, 7 logos, 2 news-tickers, 3 texts, 4.1ms
# 3: 384x640 1 face, 5 logos, 1 news-ticker, 3 texts, 4.1ms
# 4: 384x640 1 face, 5 logos, 4 news-tickers, 5 texts, 4.1ms
# 5: 384x640 1 face, 4 logos, 4 news-tickers, 5 texts, 4.1ms
# 6: 384x640 1 face, 4 logos, 4 news-tickers, 5 texts, 4.1ms
# 7: 384x640 1 face, 4 logos, 3 news-tickers, 5 texts, 4.1ms
# 8: 384x640 1 face, 3 logos, 2 news-tickers, 5 texts, 4.1ms
# Speed: 1.8ms preprocess, 4.1ms inference, 0.9ms postprocess per image at shape (9, 3, 384, 640)
# ['shifted_middle3', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'shifted_middle3', 'middle2', 'middle2', 'middle2', 'fallback_bottom', 'middle2', 'middle2', 'middle2', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 1 face, 4 logos, 3 news-tickers, 5 texts, 3.9ms
# 1: 384x640 1 face, 4 logos, 4 news-tickers, 5 texts, 3.9ms
# 2: 384x640 1 face, 5 logos, 3 news-tickers, 4 texts, 3.9ms
# 3: 384x640 2 faces, 4 logos, 3 news-tickers, 3 texts, 3.9ms
# 4: 384x640 2 faces, 3 logos, 3 news-tickers, 4 texts, 3.9ms
# 5: 384x640 1 face, 3 logos, 6 news-tickers, 4 texts, 3.9ms
# 6: 384x640 2 faces, 3 logos, 3 news-tickers, 4 texts, 3.9ms
# 7: 384x640 2 faces, 4 logos, 1 news-ticker, 4 texts, 3.9ms
# 8: 384x640 2 faces, 3 logos, 1 news-ticker, 2 texts, 3.9ms
# 9: 384x640 2 faces, 3 logos, 1 news-ticker, 2 texts, 3.9ms
# 10: 384x640 2 faces, 3 logos, 6 news-tickers, 2 texts, 3.9ms
# 11: 384x640 2 faces, 3 logos, 3 news-tickers, 2 texts, 3.9ms
# Speed: 1.6ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (12, 3, 384, 640)
# ['fallback_bottom', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'middle2', 'middle2', 'fallback_bottom', 'middle2', 'middle2', 'middle2', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 2 faces, 6 logos, 4 news-tickers, 1 sidebar, 3 texts, 4.5ms
# 1: 384x640 2 faces, 5 logos, 5 news-tickers, 1 sidebar, 3 texts, 4.5ms
# 2: 384x640 1 face, 4 logos, 4 news-tickers, 1 sidebar, 3 texts, 4.5ms
# 3: 384x640 1 face, 3 logos, 5 news-tickers, 1 sidebar, 3 texts, 4.5ms
# 4: 384x640 1 face, 3 logos, 3 news-tickers, 1 sidebar, 3 texts, 4.5ms
# 5: 384x640 2 faces, 4 logos, 5 news-tickers, 1 sidebar, 3 texts, 4.5ms
# Speed: 1.7ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (6, 3, 384, 640)
# ['fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'middle2', 'fallback_bottom', 'middle2', 'middle2', 'middle2', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 2 faces, 3 logos, 4 news-tickers, 3 texts, 4.5ms
# 1: 384x640 2 faces, 4 logos, 5 news-tickers, 1 sidebar, 3 texts, 4.5ms
# 2: 384x640 1 face, 3 logos, 4 news-tickers, 1 sidebar, 3 texts, 4.5ms
# 3: 384x640 1 face, 3 logos, 1 news-ticker, 4 texts, 4.5ms
# 4: 384x640 1 face, 4 logos, 4 news-tickers, 3 texts, 4.5ms
# 5: 384x640 1 face, 4 logos, 4 news-tickers, 4 texts, 4.5ms
# Speed: 1.7ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (6, 3, 384, 640)
# ['fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'middle2', 'middle2', 'middle2', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 1 face, 4 logos, 4 news-tickers, 4 texts, 3.9ms
# 1: 384x640 1 face, 4 logos, 5 news-tickers, 4 texts, 3.9ms
# 2: 384x640 1 face, 3 logos, 4 news-tickers, 4 texts, 3.9ms
# 3: 384x640 1 face, 4 logos, 4 news-tickers, 4 texts, 3.9ms
# 4: 384x640 1 face, 3 logos, 4 news-tickers, 5 texts, 3.9ms
# 5: 384x640 1 face, 4 logos, 4 news-tickers, 4 texts, 3.9ms
# 6: 384x640 1 face, 4 logos, 4 news-tickers, 4 texts, 3.9ms
# 7: 384x640 1 face, 4 logos, 4 news-tickers, 3 texts, 3.9ms
# 8: 384x640 1 face, 5 logos, 3 news-tickers, 4 texts, 3.9ms
# 9: 384x640 1 face, 5 logos, 3 news-tickers, 5 texts, 3.9ms
# Speed: 1.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (10, 3, 384, 640)
# ['fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'shifted_middle3', 'fallback_bottom', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'middle2', 'middle2', 'middle2', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 1 face, 5 logos, 3 news-tickers, 5 texts, 4.5ms
# 1: 384x640 1 face, 5 logos, 3 news-tickers, 5 texts, 4.5ms
# 2: 384x640 1 face, 5 logos, 4 news-tickers, 5 texts, 4.5ms
# 3: 384x640 1 face, 4 logos, 2 news-tickers, 4 texts, 4.5ms
# 4: 384x640 1 face, 4 logos, 3 news-tickers, 5 texts, 4.5ms
# 5: 384x640 1 face, 4 logos, 4 news-tickers, 5 texts, 4.5ms
# Speed: 1.7ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (6, 3, 384, 640)
# ['fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'shifted_middle3', 'middle2', 'middle2', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 1 face, 4 logos, 4 news-tickers, 5 texts, 4.5ms
# 1: 384x640 1 face, 4 logos, 4 news-tickers, 5 texts, 4.5ms
# 2: 384x640 1 face, 4 logos, 5 news-tickers, 5 texts, 4.5ms
# 3: 384x640 2 faces, 6 logos, 4 news-tickers, 3 texts, 4.5ms
# 4: 384x640 1 face, 8 logos, 3 news-tickers, 1 sidebar, 4 texts, 4.5ms
# 5: 384x640 2 faces, 6 logos, 4 news-tickers, 4 texts, 4.5ms
# Speed: 1.7ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (6, 3, 384, 640)
# ['shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'middle2', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 2 faces, 5 logos, 4 news-tickers, 4 texts, 3.9ms
# 1: 384x640 2 faces, 5 logos, 4 news-tickers, 4 texts, 3.9ms
# 2: 384x640 1 face, 5 logos, 2 news-tickers, 4 texts, 3.9ms
# 3: 384x640 2 faces, 5 logos, 3 news-tickers, 1 sidebar, 4 texts, 3.9ms
# 4: 384x640 2 faces, 3 logos, 3 news-tickers, 1 sidebar, 3 texts, 3.9ms
# 5: 384x640 3 faces, 2 logos, 3 news-tickers, 1 sidebar, 4 texts, 3.9ms
# 6: 384x640 1 face, 2 logos, 1 news-ticker, 1 sidebar, 3 texts, 3.9ms
# 7: 384x640 1 face, 3 logos, 3 news-tickers, 1 sidebar, 2 texts, 3.9ms
# 8: 384x640 1 face, 3 logos, 3 news-tickers, 1 sidebar, 3 texts, 3.9ms
# 9: 384x640 2 faces, 3 logos, 4 news-tickers, 3 texts, 3.9ms
# 10: 384x640 2 faces, 3 logos, 2 news-tickers, 3 texts, 3.9ms
# 11: 384x640 2 faces, 4 logos, 3 news-tickers, 3 texts, 3.9ms
# Speed: 1.6ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (12, 3, 384, 640)
# ['fallback_bottom', 'fallback_bottom', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'shifted_top', 'shifted_top', 'fallback_bottom', 'fallback_bottom', 'shifted_middle3', 'fallback_bottom', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 2 faces, 4 logos, 2 news-tickers, 2 texts, 4.5ms
# 1: 384x640 1 face, 5 logos, 4 news-tickers, 2 texts, 4.5ms
# 2: 384x640 1 face, 1 logo, 1 news-ticker, 4 texts, 4.5ms
# 3: 384x640 1 face, 1 logo, 1 news-ticker, 5 texts, 4.5ms
# 4: 384x640 1 face, 1 logo, 1 news-ticker, 4 texts, 4.5ms
# 5: 384x640 1 logo, 1 news-ticker, 4 texts, 4.5ms
# Speed: 1.8ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (6, 3, 384, 640)
# ['fallback_bottom', 'fallback_bottom', 'middle2', 'middle2', 'middle2', 'middle2', 'shifted_middle3', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 1 face, 1 logo, 1 news-ticker, 4 texts, 4.1ms
# 1: 384x640 1 face, 1 logo, 3 news-tickers, 5 texts, 4.1ms
# 2: 384x640 1 face, 1 logo, 5 news-tickers, 4 texts, 4.1ms
# 3: 384x640 1 logo, 3 news-tickers, 4 texts, 4.1ms
# 4: 384x640 1 face, 1 logo, 2 news-tickers, 4 texts, 4.1ms
# 5: 384x640 1 face, 1 logo, 2 news-tickers, 4 texts, 4.1ms
# 6: 384x640 1 face, 1 logo, 2 news-tickers, 4 texts, 4.1ms
# 7: 384x640 1 face, 3 logos, 3 news-tickers, 2 texts, 4.1ms
# 8: 384x640 1 face, 3 logos, 3 news-tickers, 2 texts, 4.1ms
# Speed: 1.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (9, 3, 384, 640)
# ['middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'shifted_top', 'shifted_top', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 1 face, 3 logos, 3 news-tickers, 2 texts, 4.5ms
# 1: 384x640 1 face, 3 logos, 4 news-tickers, 2 texts, 4.5ms
# 2: 384x640 1 face, 3 logos, 4 news-tickers, 2 texts, 4.5ms
# 3: 384x640 1 face, 3 logos, 4 news-tickers, 2 texts, 4.5ms
# 4: 384x640 1 face, 3 logos, 6 news-tickers, 2 texts, 4.5ms
# 5: 384x640 1 face, 3 logos, 4 news-tickers, 2 texts, 4.5ms
# Speed: 1.7ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (6, 3, 384, 640)
# ['shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_top', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 1 face, 3 logos, 1 news-ticker, 2 texts, 4.1ms
# 1: 384x640 1 face, 3 logos, 4 news-tickers, 2 texts, 4.1ms
# 2: 384x640 1 face, 3 logos, 4 news-tickers, 2 texts, 4.1ms
# 3: 384x640 1 face, 3 logos, 3 news-tickers, 1 text, 4.1ms
# 4: 384x640 2 faces, 3 logos, 4 news-tickers, 1 text, 4.1ms
# 5: 384x640 1 face, 4 logos, 3 news-tickers, 1 sidebar, 1 text, 4.1ms
# 6: 384x640 1 face, 3 logos, 1 news-ticker, 1 sidebar, 1 text, 4.1ms
# 7: 384x640 1 face, 3 logos, 1 news-ticker, 1 sidebar, 1 text, 4.1ms
# 8: 384x640 1 face, 2 logos, 1 news-ticker, 1 sidebar, 1 text, 4.1ms
# Speed: 1.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (9, 3, 384, 640)
# ['shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 1 face, 2 logos, 1 news-ticker, 1 sidebar, 1 text, 4.4ms
# 1: 384x640 2 faces, 2 logos, 1 news-ticker, 1 sidebar, 1 text, 4.4ms
# 2: 384x640 1 face, 3 logos, 2 news-tickers, 1 sidebar, 1 text, 4.4ms
# 3: 384x640 1 face, 4 logos, 2 news-tickers, 1 text, 4.4ms
# 4: 384x640 1 face, 3 logos, 1 news-ticker, 1 text, 4.4ms
# 5: 384x640 1 face, 3 logos, 2 news-tickers, 1 text, 4.4ms
# 6: 384x640 2 faces, 3 logos, 1 news-ticker, 1 sidebar, 1 text, 4.4ms
# Speed: 1.6ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (7, 3, 384, 640)
# ['shifted_top', 'shifted_top', 'shifted_top', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_top', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 1 face, 3 logos, 1 news-ticker, 1 sidebar, 1 text, 5.7ms
# 1: 384x640 2 faces, 3 logos, 2 news-tickers, 1 sidebar, 1 text, 5.7ms
# 2: 384x640 2 faces, 3 logos, 2 news-tickers, 1 sidebar, 1 text, 5.7ms
# Speed: 1.9ms preprocess, 5.7ms inference, 0.9ms postprocess per image at shape (3, 3, 384, 640)
# ['shifted_top', 'shifted_top', 'shifted_top', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 2 faces, 4 logos, 1 news-ticker, 1 sidebar, 1 text, 4.5ms
# 1: 384x640 2 faces, 4 logos, 1 news-ticker, 1 text, 4.5ms
# 2: 384x640 2 faces, 4 logos, 1 news-ticker, 1 sidebar, 1 text, 4.5ms
# 3: 384x640 2 faces, 4 logos, 2 news-tickers, 1 sidebar, 1 text, 4.5ms
# 4: 384x640 2 faces, 3 logos, 2 news-tickers, 1 sidebar, 1 text, 4.5ms
# 5: 384x640 1 face, 3 logos, 1 news-ticker, 1 sidebar, 1 text, 4.5ms
# Speed: 1.8ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (6, 3, 384, 640)
# ['shifted_top', 'shifted_middle3', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 1 face, 4 logos, 1 news-ticker, 2 texts, 4.5ms
# 1: 384x640 1 face, 3 logos, 1 news-ticker, 2 texts, 4.5ms
# 2: 384x640 1 face, 4 logos, 1 news-ticker, 2 texts, 4.5ms
# 3: 384x640 1 face, 3 logos, 2 news-tickers, 2 texts, 4.5ms
# 4: 384x640 1 face, 3 logos, 1 news-ticker, 1 text, 4.5ms
# 5: 384x640 1 face, 3 logos, 1 news-ticker, 1 text, 4.5ms
# Speed: 1.8ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (6, 3, 384, 640)
# ['shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 1 face, 3 logos, 2 news-tickers, 2 texts, 4.1ms
# 1: 384x640 1 face, 3 logos, 2 news-tickers, 2 texts, 4.1ms
# 2: 384x640 1 face, 3 logos, 3 news-tickers, 1 text, 4.1ms
# 3: 384x640 1 face, 3 logos, 1 news-ticker, 1 text, 4.1ms
# 4: 384x640 1 face, 3 logos, 1 news-ticker, 2 texts, 4.1ms
# 5: 384x640 1 face, 3 logos, 1 news-ticker, 2 texts, 4.1ms
# 6: 384x640 1 face, 3 logos, 1 news-ticker, 2 texts, 4.1ms
# 7: 384x640 1 face, 3 logos, 2 news-tickers, 1 text, 4.1ms
# 8: 384x640 1 face, 3 logos, 1 news-ticker, 1 text, 4.1ms
# Speed: 1.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (9, 3, 384, 640)
# ['shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 1 face, 2 logos, 2 news-tickers, 1 text, 4.5ms
# 1: 384x640 1 face, 3 logos, 2 news-tickers, 1 text, 4.5ms
# 2: 384x640 1 face, 3 logos, 1 news-ticker, 1 text, 4.5ms
# 3: 384x640 1 face, 3 logos, 1 news-ticker, 2 texts, 4.5ms
# 4: 384x640 1 face, 3 logos, 2 news-tickers, 2 texts, 4.5ms
# 5: 384x640 1 face, 3 logos, 4 news-tickers, 3 texts, 4.5ms
# Speed: 1.7ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (6, 3, 384, 640)
# ['shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_top', 'shifted_top', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 2 faces, 3 logos, 1 news-ticker, 1 text, 4.6ms
# 1: 384x640 1 face, 4 logos, 4 news-tickers, 1 sidebar, 1 text, 4.6ms
# 2: 384x640 1 face, 3 logos, 3 news-tickers, 1 text, 4.6ms
# 3: 384x640 1 face, 3 logos, 3 news-tickers, 1 text, 4.6ms
# 4: 384x640 1 face, 3 logos, 3 news-tickers, 1 text, 4.6ms
# 5: 384x640 2 faces, 3 logos, 2 news-tickers, 2 texts, 4.6ms
# Speed: 2.3ms preprocess, 4.6ms inference, 1.1ms postprocess per image at shape (6, 3, 384, 640)
# ['shifted_top', 'shifted_top', 'shifted_middle3', 'shifted_top', 'shifted_middle3', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 2 faces, 3 logos, 2 news-tickers, 2 texts, 4.5ms
# 1: 384x640 2 faces, 2 logos, 5 news-tickers, 1 text, 4.5ms
# 2: 384x640 2 faces, 2 logos, 5 news-tickers, 1 text, 4.5ms
# 3: 384x640 2 faces, 3 logos, 5 news-tickers, 1 text, 4.5ms
# 4: 384x640 2 faces, 3 logos, 5 news-tickers, 1 text, 4.5ms
# 5: 384x640 2 faces, 3 logos, 5 news-tickers, 2 texts, 4.5ms
# Speed: 3.0ms preprocess, 4.5ms inference, 1.0ms postprocess per image at shape (6, 3, 384, 640)
# ['shifted_middle3', 'shifted_middle3', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 2 faces, 3 logos, 5 news-tickers, 2 texts, 4.1ms
# 1: 384x640 2 faces, 3 logos, 4 news-tickers, 2 texts, 4.1ms
# 2: 384x640 2 faces, 3 logos, 3 news-tickers, 2 texts, 4.1ms
# 3: 384x640 2 faces, 3 logos, 1 news-ticker, 1 text, 4.1ms
# 4: 384x640 2 faces, 3 logos, 3 news-tickers, 2 texts, 4.1ms
# 5: 384x640 2 faces, 3 logos, 4 news-tickers, 1 text, 4.1ms
# 6: 384x640 2 faces, 2 logos, 4 news-tickers, 1 sidebar, 2 texts, 4.1ms
# 7: 384x640 2 faces, 2 logos, 5 news-tickers, 2 texts, 4.1ms
# 8: 384x640 1 face, 3 logos, 3 news-tickers, 1 sidebar, 2 texts, 4.1ms
# Speed: 2.0ms preprocess, 4.1ms inference, 0.9ms postprocess per image at shape (9, 3, 384, 640)
# ['shifted_top', 'shifted_middle3', 'shifted_top', 'shifted_top', 'shifted_middle3', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 1 face, 3 logos, 5 news-tickers, 3 texts, 4.0ms
# 1: 384x640 1 face, 3 logos, 4 news-tickers, 3 texts, 4.0ms
# 2: 384x640 1 face, 3 logos, 5 news-tickers, 3 texts, 4.0ms
# 3: 384x640 1 face, 3 logos, 3 news-tickers, 3 texts, 4.0ms
# 4: 384x640 1 face, 3 logos, 3 news-tickers, 3 texts, 4.0ms
# 5: 384x640 1 face, 3 logos, 2 news-tickers, 2 texts, 4.0ms
# 6: 384x640 1 face, 3 logos, 3 news-tickers, 3 texts, 4.0ms
# 7: 384x640 1 face, 3 logos, 2 news-tickers, 3 texts, 4.0ms
# 8: 384x640 1 face, 3 logos, 2 news-tickers, 3 texts, 4.0ms
# Speed: 1.9ms preprocess, 4.0ms inference, 1.2ms postprocess per image at shape (9, 3, 384, 640)
# ['shifted_top', 'shifted_middle3', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 1 face, 3 logos, 1 news-ticker, 3 texts, 4.2ms
# 1: 384x640 1 face, 3 logos, 4 news-tickers, 3 texts, 4.2ms
# 2: 384x640 1 face, 3 logos, 3 news-tickers, 2 texts, 4.2ms
# 3: 384x640 2 faces, 3 logos, 3 news-tickers, 3 texts, 4.2ms
# 4: 384x640 1 face, 3 logos, 3 news-tickers, 3 texts, 4.2ms
# 5: 384x640 1 face, 3 logos, 3 news-tickers, 3 texts, 4.2ms
# 6: 384x640 1 face, 2 logos, 3 news-tickers, 2 texts, 4.2ms
# 7: 384x640 1 face, 2 logos, 2 news-tickers, 2 texts, 4.2ms
# Speed: 2.5ms preprocess, 4.2ms inference, 1.3ms postprocess per image at shape (8, 3, 384, 640)
# ['shifted_top', 'shifted_top', 'shifted_middle3', 'fallback_bottom', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'shifted_middle3', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 1 face, 3 logos, 4 news-tickers, 2 texts, 5.7ms
# 1: 384x640 1 face, 3 logos, 3 news-tickers, 2 texts, 5.7ms
# 2: 384x640 1 face, 3 logos, 3 news-tickers, 2 texts, 5.7ms
# 3: 384x640 1 face, 3 logos, 3 news-tickers, 2 texts, 5.7ms
# 4: 384x640 1 face, 3 logos, 3 news-tickers, 2 texts, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 1.3ms postprocess per image at shape (5, 3, 384, 640)
# ['shifted_top', 'shifted_top', 'shifted_middle3', 'shifted_top', 'shifted_top', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 1 face, 3 logos, 3 news-tickers, 1 text, 4.1ms
# 1: 384x640 2 faces, 3 logos, 4 news-tickers, 1 text, 4.1ms
# 2: 384x640 2 faces, 2 logos, 4 news-tickers, 1 text, 4.1ms
# 3: 384x640 2 faces, 2 logos, 1 news-ticker, 1 text, 4.1ms
# 4: 384x640 2 faces, 2 logos, 1 news-ticker, 1 sidebar, 3 texts, 4.1ms
# 5: 384x640 2 faces, 2 logos, 4 news-tickers, 2 texts, 4.1ms
# 6: 384x640 2 faces, 2 logos, 4 news-tickers, 1 text, 4.1ms
# 7: 384x640 2 faces, 2 logos, 4 news-tickers, 2 texts, 4.1ms
# 8: 384x640 2 faces, 2 logos, 4 news-tickers, 2 texts, 4.1ms
# Speed: 1.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (9, 3, 384, 640)
# ['shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 2 faces, 3 logos, 4 news-tickers, 1 sidebar, 2 texts, 4.4ms
# 1: 384x640 1 face, 3 logos, 4 news-tickers, 2 texts, 4.4ms
# 2: 384x640 2 faces, 3 logos, 4 news-tickers, 1 sidebar, 2 texts, 4.4ms
# 3: 384x640 2 faces, 3 logos, 4 news-tickers, 1 sidebar, 2 texts, 4.4ms
# 4: 384x640 2 faces, 4 logos, 4 news-tickers, 1 sidebar, 2 texts, 4.4ms
# 5: 384x640 2 faces, 3 logos, 3 news-tickers, 1 sidebar, 2 texts, 4.4ms
# 6: 384x640 2 faces, 2 logos, 3 news-tickers, 1 sidebar, 2 texts, 4.4ms
# Speed: 1.7ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (7, 3, 384, 640)
# ['shifted_top', 'middle2', 'shifted_top', 'shifted_top', 'fallback_bottom', 'shifted_top', 'shifted_top', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 1 face, 1 logo, 2 news-tickers, 1 sidebar, 4 texts, 4.0ms
# 1: 384x640 1 face, 1 logo, 2 news-tickers, 1 sidebar, 4 texts, 4.0ms
# 2: 384x640 1 face, 1 logo, 2 news-tickers, 1 sidebar, 4 texts, 4.0ms
# 3: 384x640 2 faces, 1 logo, 2 news-tickers, 1 sidebar, 4 texts, 4.0ms
# 4: 384x640 1 face, 1 logo, 2 news-tickers, 4 texts, 4.0ms
# 5: 384x640 1 logo, 2 news-tickers, 5 texts, 4.0ms
# 6: 384x640 1 logo, 3 news-tickers, 4 texts, 4.0ms
# 7: 384x640 1 logo, 3 news-tickers, 5 texts, 4.0ms
# 8: 384x640 1 logo, 2 news-tickers, 5 texts, 4.0ms
# 9: 384x640 1 face, 3 logos, 4 news-tickers, 3 texts, 4.0ms
# 10: 384x640 1 face, 3 logos, 5 news-tickers, 3 texts, 4.0ms
# 11: 384x640 1 face, 3 logos, 3 news-tickers, 3 texts, 4.0ms
# Speed: 1.6ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (12, 3, 384, 640)
# ['middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'shifted_top', 'shifted_top', 'shifted_top', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 1 face, 3 logos, 4 news-tickers, 3 texts, 4.8ms
# 1: 384x640 1 face, 3 logos, 4 news-tickers, 3 texts, 4.8ms
# 2: 384x640 1 face, 3 logos, 3 news-tickers, 3 texts, 4.8ms
# 3: 384x640 1 face, 3 logos, 4 news-tickers, 3 texts, 4.8ms
# Speed: 2.0ms preprocess, 4.8ms inference, 0.9ms postprocess per image at shape (4, 3, 384, 640)
# ['shifted_top', 'shifted_middle3', 'shifted_middle3', 'shifted_top', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 1 face, 3 logos, 4 news-tickers, 3 texts, 3.9ms
# 1: 384x640 1 face, 3 logos, 5 news-tickers, 3 texts, 3.9ms
# 2: 384x640 1 face, 2 logos, 4 news-tickers, 2 texts, 3.9ms
# 3: 384x640 1 face, 3 logos, 1 news-ticker, 3 texts, 3.9ms
# 4: 384x640 1 face, 3 logos, 3 news-tickers, 3 texts, 3.9ms
# 5: 384x640 1 face, 3 logos, 2 news-tickers, 3 texts, 3.9ms
# 6: 384x640 1 face, 3 logos, 4 news-tickers, 3 texts, 3.9ms
# 7: 384x640 1 face, 3 logos, 3 news-tickers, 3 texts, 3.9ms
# 8: 384x640 1 face, 3 logos, 4 news-tickers, 3 texts, 3.9ms
# 9: 384x640 1 face, 3 logos, 3 news-tickers, 3 texts, 3.9ms
# 10: 384x640 1 face, 2 logos, 4 news-tickers, 3 texts, 3.9ms
# 11: 384x640 1 face, 2 logos, 4 news-tickers, 2 texts, 3.9ms
# Speed: 1.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (12, 3, 384, 640)
# ['shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_middle3', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: shifted_top
#
# 0: 384x640 1 face, 3 logos, 3 news-tickers, 3 texts, 4.4ms
# 1: 384x640 1 face, 3 logos, 4 news-tickers, 1 sidebar, 2 texts, 4.4ms
# 2: 384x640 2 faces, 2 logos, 3 news-tickers, 1 sidebar, 2 texts, 4.4ms
# 3: 384x640 2 faces, 3 logos, 3 news-tickers, 1 text, 4.4ms
# 4: 384x640 2 faces, 3 logos, 2 news-tickers, 1 text, 4.4ms
# 5: 384x640 2 faces, 3 logos, 3 news-tickers, 2 texts, 4.4ms
# 6: 384x640 2 faces, 2 logos, 2 news-tickers, 1 sidebar, 1 text, 4.4ms
# Speed: 1.8ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (7, 3, 384, 640)
# ['shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_middle3', 'shifted_top', 'shifted_top', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'shifted_top']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 2 faces, 2 logos, 1 news-ticker, 2 texts, 4.3ms
# 1: 384x640 2 faces, 3 logos, 2 news-tickers, 2 texts, 4.3ms
# 2: 384x640 3 faces, 3 logos, 2 news-tickers, 1 sidebar, 2 texts, 4.3ms
# 3: 384x640 2 faces, 3 logos, 1 news-ticker, 1 text, 4.3ms
# 4: 384x640 2 faces, 4 logos, 1 news-ticker, 1 sidebar, 1 text, 4.3ms
# 5: 384x640 2 faces, 3 logos, 1 news-ticker, 1 sidebar, 1 text, 4.3ms
# 6: 384x640 2 faces, 1 logo, 2 news-tickers, 1 sidebar, 3 texts, 4.3ms
# Speed: 1.7ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (7, 3, 384, 640)
# ['shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'shifted_top', 'middle2', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'shifted_top', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 2 faces, 1 logo, 3 news-tickers, 1 sidebar, 3 texts, 4.1ms
# 1: 384x640 2 faces, 3 logos, 2 news-tickers, 1 sidebar, 3 texts, 4.1ms
# 2: 384x640 2 faces, 1 logo, 2 news-tickers, 3 texts, 4.1ms
# 3: 384x640 2 faces, 1 logo, 2 news-tickers, 3 texts, 4.1ms
# 4: 384x640 2 faces, 1 logo, 2 news-tickers, 1 sidebar, 4 texts, 4.1ms
# 5: 384x640 2 faces, 2 logos, 2 news-tickers, 4 texts, 4.1ms
# 6: 384x640 2 faces, 1 logo, 2 news-tickers, 3 texts, 4.1ms
# 7: 384x640 3 logos, 1 news-ticker, 2 texts, 4.1ms
# 8: 384x640 1 face, 3 logos, 1 news-ticker, 1 sidebar, 3 texts, 4.1ms
# Speed: 1.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (9, 3, 384, 640)
# ['middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'middle2', 'shifted_top', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'fallback_bottom', 'shifted_top', 'fallback_bottom', 'fallback_bottom']
# ✅ Final Safe Zone: fallback_bottom
#
# 0: 384x640 1 face, 3 logos, 1 news-ticker, 3 texts, 4.6ms
# 1: 384x640 1 face, 3 logos, 2 news-tickers, 3 texts, 4.6ms
# 2: 384x640 1 face, 3 logos, 2 news-tickers, 3 texts, 4.6ms
# 3: 384x640 1 face, 3 logos, 2 news-tickers, 3 texts, 4.6ms
# 4: 384x640 1 face, 3 logos, 1 news-ticker, 3 texts, 4.6ms
# 5: 384x640 1 face, 3 logos, 2 news-tickers, 3 texts, 4.6ms
# ...
#       <p begin="2528.359s" xml:id="p851" end="2530.68s">proposed minerals deal between the two</p>
#       <p begin="2530.68s" xml:id="p852" end="2534.16s">countries Ross Cullen CNA</p>
#       <p begin="2534.16s" xml:id="p853" end="2537.079s">ke well earlier we spoke with Dr Peter</p>
#       <p begin="2537.079s" xml:id="p854" end="2539.4s">Leighton a visiting fellow of Griffith</p>
#       <p begin="2539.4s" xml:id="p855" end="2541.76s">Asia Institute at Griffith University</p>
#       <p begin="2541.76s" xml:id="p856" end="2543.72s">and he shares his views on Europe's</p>
#       <p begin="2543.72s" xml:id="p857" end="2545.88s">military Readiness the shifting arms</p>
#       <p begin="2545.88s" xml:id="p858" end="2548.4s">trade and the impact of global tensions</p>
#       <p begin="2548.4s" xml:id="p859" end="2550.319s">on defense</p>
#       <p begin="2550.319s" xml:id="p860" end="2554.96s">strategies the Ukrainian War has has I</p>
#       <p begin="2554.96s" xml:id="p861" end="2557.119s">IED Russian forces particularly their</p>
#       <p begin="2557.119s" xml:id="p862" end="2559.68s">mechanized forces and their army their</p>
#       <p begin="2559.68s" xml:id="p863" end="2561.76s">Air Force is sort of 10% lower now</p>
#       <p begin="2561.76s" xml:id="p864" end="2563.839s">because they've lost 10% of their</p>
#       <p begin="2563.839s" xml:id="p865" end="2566.16s">aircraft the problem that the Europeans</p>
#       <p begin="2566.16s" xml:id="p866" end="2568.2s">have though is that if you want to ramp</p>
#       <p begin="2568.2s" xml:id="p867" end="2570.76s">up your Defense Forces quickly that is</p>
#       <p begin="2570.76s" xml:id="p868" end="2572.76s">extremely difficult there's normally a</p>
#       <p begin="2572.76s" xml:id="p869" end="2575.16s">lead time of 3 to 5 years and the</p>
#       <p begin="2575.16s" xml:id="p870" end="2577.68s">Americans can be can be quite slow about</p>
#       <p begin="2577.68s" xml:id="p871" end="2579.76s">delivering weapons you have ordered the</p>
#       <p begin="2579.76s" xml:id="p872" end="2581.64s">Americans only have one production line</p>
#       <p begin="2581.64s" xml:id="p873" end="2584.52s">for for for or most of their kit and</p>
#       <p begin="2584.52s" xml:id="p874" end="2587.28s">they have large orders so ramping up</p>
#       <p begin="2587.28s" xml:id="p875" end="2590.319s">quickly is a big ask Europeans are now</p>
#       <p begin="2590.319s" xml:id="p876" end="2591.96s">shopping around the world and South</p>
#       <p begin="2591.96s" xml:id="p877" end="2593.839s">Korea and various countries of that are</p>
#       <p begin="2593.839s" xml:id="p878" end="2596.599s">the benefits of this all right I'd love</p>
#       <p begin="2596.599s" xml:id="p879" end="2598.2s">to talk about the trickle down effects</p>
#       <p begin="2598.2s" xml:id="p880" end="2600.319s">in a moment but first I just want to ask</p>
#       <p begin="2600.319s" xml:id="p881" end="2602.64s">you about another report that came out a</p>
#       <p begin="2602.64s" xml:id="p882" end="2604.52s">few weeks ago the military balance</p>
#       <p begin="2604.52s" xml:id="p883" end="2606.48s">report it says that Russia's military</p>
#       <p begin="2606.48s" xml:id="p884" end="2608.44s">expenditure is is rising outperforming</p>
#       <p begin="2608.44s" xml:id="p885" end="2611.119s">All European countries combined at this</p>
#       <p begin="2611.119s" xml:id="p886" end="2613.96s">rate how soon can Europe realistically</p>
#       <p begin="2613.96s" xml:id="p887" end="2616.44s">arm itself sufficiently if they are to</p>
#       <p begin="2616.44s" xml:id="p888" end="2619.8s">be concerned with the Russian</p>
#       <p begin="2620.079s" xml:id="p889" end="2623.96s">threat yes so so the Russians are reing</p>
#       <p begin="2623.96s" xml:id="p890" end="2626.079s">but but lots of it tends to be</p>
#       <p begin="2626.079s" xml:id="p891" end="2627.72s">relatively simple equipment for the</p>
#       <p begin="2627.72s" xml:id="p892" end="2629.76s">ground offensive like if you like the</p>
#       <p begin="2629.76s" xml:id="p893" end="2632.0s">artillery shells um and the cost of</p>
#       <p begin="2632.0s" xml:id="p894" end="2634.44s">raising the size of their army is is</p>
#       <p begin="2634.44s" xml:id="p895" end="2636.44s">significant the Europeans certainly have</p>
#       <p begin="2636.44s" xml:id="p896" end="2638.64s">the potential of fing a much larger</p>
#       <p begin="2638.64s" xml:id="p897" end="2640.839s">military and of course the Russians the</p>
#       <p begin="2640.839s" xml:id="p898" end="2642.839s">moment are trying to rebuild their their</p>
#       <p begin="2642.839s" xml:id="p899" end="2645.16s">their military as well having having</p>
#       <p begin="2645.16s" xml:id="p900" end="2647.2s">having suffered losses over the last</p>
#       <p begin="2647.2s" xml:id="p901" end="2648.52s">three</p>
#       <p begin="2648.52s" xml:id="p902" end="2650.76s">years can you talk to us about the</p>
#       <p begin="2650.76s" xml:id="p903" end="2652.88s">opportunities then back to your first</p>
#       <p begin="2652.88s" xml:id="p904" end="2656.48s">point for other arms um makers like</p>
#       <p begin="2656.48s" xml:id="p905" end="2660.92s">India China or even Russia in this</p>
#       <p begin="2661.64s" xml:id="p906" end="2663.599s">juncture I don't think there's much</p>
#       <p begin="2663.599s" xml:id="p907" end="2665.599s">chance of the Russians and it's not just</p>
#       <p begin="2665.599s" xml:id="p908" end="2667.599s">because they're fighting the Russians</p>
#       <p begin="2667.599s" xml:id="p909" end="2669.119s">are having a lot of trouble building</p>
#       <p begin="2669.119s" xml:id="p910" end="2671.559s">sophisticated arms uh the Indians for</p>
#       <p begin="2671.559s" xml:id="p911" end="2673.599s">instance have been uh over the last four</p>
#       <p begin="2673.599s" xml:id="p912" end="2675.839s">or five years have been ordering many</p>
#       <p begin="2675.839s" xml:id="p913" end="2677.04s">arms from</p>
#       <p begin="2677.04s" xml:id="p914" end="2679.92s">Russia uh but but most of the arms that</p>
#       <p begin="2679.92s" xml:id="p915" end="2681.76s">they' have ordered have not turned up</p>
#       <p begin="2681.76s" xml:id="p916" end="2683.24s">they're they're either being used in the</p>
#       <p begin="2683.24s" xml:id="p917" end="2687.079s">war or to rebuild Russian forces so</p>
#       <p begin="2687.079s" xml:id="p918" end="2689.68s">Russia as a as a as a supplier is rather</p>
#       <p begin="2689.68s" xml:id="p919" end="2691.44s">doubtful at the moment it's probably and</p>
#       <p begin="2691.44s" xml:id="p920" end="2693.76s">unreliable while looking forward I think</p>
#       <p begin="2693.76s" xml:id="p921" end="2695.8s">there's sort of options for say South</p>
#       <p begin="2695.8s" xml:id="p922" end="2699.24s">Korea Japan maybe um there there's a</p>
#       <p begin="2699.24s" xml:id="p923" end="2701.8s">range of countries I mean um the the the</p>
#       <p begin="2701.8s" xml:id="p924" end="2703.72s">Europeans as you said France is the</p>
#       <p begin="2703.72s" xml:id="p925" end="2705.839s">France is the second largest</p>
#       <p begin="2705.839s" xml:id="p926" end="2708.16s">exporter so other countries around the</p>
#       <p begin="2708.16s" xml:id="p927" end="2710.48s">world uh May benefit Australia for</p>
#       <p begin="2710.48s" xml:id="p928" end="2712.24s">instance there there's there's a few</p>
#       <p begin="2712.24s" xml:id="p929" end="2714.88s">arms manufactors here who are exporting</p>
#       <p begin="2714.88s" xml:id="p930" end="2719.16s">artillery shells Etc into into Germany</p>
#       <p begin="2719.16s" xml:id="p931" end="2722.0s">all right U well the war in Ukraine Dr</p>
#       <p begin="2722.0s" xml:id="p932" end="2724.359s">Leighton has played a major role in</p>
#       <p begin="2724.359s" xml:id="p933" end="2727.079s">improving us dominance in the arms trade</p>
#       <p begin="2727.079s" xml:id="p934" end="2729.92s">so how will a potential ceasefire that's</p>
#       <p begin="2729.92s" xml:id="p935" end="2733.0s">currently being worked on in Kev affect</p>
#       <p begin="2733.0s" xml:id="p936" end="2736.64s">defense firms in the United</p>
#       <p begin="2736.92s" xml:id="p937" end="2739.359s">States uh this is this is this is an</p>
#       <p begin="2739.359s" xml:id="p938" end="2740.599s">interesting question because a couple of</p>
#       <p begin="2740.599s" xml:id="p939" end="2744.4s">tensions here um so at the present time</p>
#       <p begin="2744.4s" xml:id="p940" end="2747.72s">the the uh Europeans are principally</p>
#       <p begin="2747.72s" xml:id="p941" end="2750.28s">buying as you said sort of American Arms</p>
#       <p begin="2750.28s" xml:id="p942" end="2752.72s">because in the age of globalization that</p>
#       <p begin="2752.72s" xml:id="p943" end="2754.96s">we've just left the the Americans were</p>
#       <p begin="2754.96s" xml:id="p944" end="2757.16s">pretty much a Sal sour supplier and the</p>
#       <p begin="2757.16s" xml:id="p945" end="2758.8s">competitive advantage that that that the</p>
#       <p begin="2758.8s" xml:id="p946" end="2761.119s">Americans held was very high the</p>
#       <p begin="2761.119s" xml:id="p947" end="2763.96s">Europeans were unconcerned about any um</p>
#       <p begin="2763.96s" xml:id="p948" end="2766.44s">American dominance to sort of to a point</p>
#       <p begin="2766.44s" xml:id="p949" end="2768.28s">because they they had strong confidence</p>
#       <p begin="2768.28s" xml:id="p950" end="2771.76s">they could rely upon the Americans that</p>
#       <p begin="2771.76s" xml:id="p951" end="2773.599s">uh that confidence about relying on the</p>
#       <p begin="2773.599s" xml:id="p952" end="2776.24s">Americans is now Vanishing daily and the</p>
#       <p begin="2776.24s" xml:id="p953" end="2778.4s">and the Americans uh cutting off the</p>
#       <p begin="2778.4s" xml:id="p954" end="2782.04s">intelligence data has really dealt at a</p>
#       <p begin="2782.04s" xml:id="p955" end="2785.359s">are are a big blow so the Europeans for</p>
#       <p begin="2785.359s" xml:id="p956" end="2787.079s">their more sophisticated equipment such</p>
#       <p begin="2787.079s" xml:id="p957" end="2790.359s">as the F35 fighter are now are getting</p>
#       <p begin="2790.359s" xml:id="p958" end="2793.0s">concerned about well the Americans have</p>
#       <p begin="2793.0s" xml:id="p959" end="2794.4s">the ability with their software and</p>
#       <p begin="2794.4s" xml:id="p960" end="2796.0s">their various means that they could</p>
#       <p begin="2796.0s" xml:id="p961" end="2798.24s">actually stop European fighter fleets</p>
#       <p begin="2798.24s" xml:id="p962" end="2799.96s">from operating that there's a kill</p>
#       <p begin="2799.96s" xml:id="p963" end="2802.28s">switch there so the Europeans think at</p>
#       <p begin="2802.28s" xml:id="p964" end="2805.16s">least with that idea in their mind if</p>
#       <p begin="2805.16s" xml:id="p965" end="2807.44s">there is peace in the Ukraine and it</p>
#       <p begin="2807.44s" xml:id="p966" end="2809.319s">gives them a breathing space the</p>
#       <p begin="2809.319s" xml:id="p967" end="2811.44s">Europeans will probably be be more</p>
#       <p begin="2811.44s" xml:id="p968" end="2813.079s">inclined to build up their own arms</p>
#       <p begin="2813.079s" xml:id="p969" end="2814.8s">industry and move away from the</p>
#       <p begin="2814.8s" xml:id="p970" end="2818.079s">Americans as fast as they can</p>
#       <p begin="2818.079s" xml:id="p971" end="2821.0s">and about the NATO countries involved in</p>
#       <p begin="2821.0s" xml:id="p972" end="2823.559s">this whole discussion of the war are</p>
#       <p begin="2823.559s" xml:id="p973" end="2825.76s">they likely to give in to president</p>
#       <p begin="2825.76s" xml:id="p974" end="2828.52s">Trump's call of buying even more arms</p>
#       <p begin="2828.52s" xml:id="p975" end="2831.24s">from Washington what's your take on this</p>
#       <p begin="2831.24s" xml:id="p976" end="2833.119s">especially in the face of you know</p>
#       <p begin="2833.119s" xml:id="p977" end="2836.64s">tariffs and and discussions like</p>
#       <p begin="2836.64s" xml:id="p978" end="2840.0s">that it does seem unlikely and I suppose</p>
#       <p begin="2840.0s" xml:id="p979" end="2841.839s">you can see that in the share market in</p>
#       <p begin="2841.839s" xml:id="p980" end="2843.52s">that European Defense stocks have risen</p>
#       <p begin="2843.52s" xml:id="p981" end="2845.88s">sharply and American defense stocks are</p>
#       <p begin="2845.88s" xml:id="p982" end="2850.2s">falling so I think so I think the idea</p>
#       <p begin="2850.2s" xml:id="p983" end="2852.76s">it's the old story of of the Trump ad</p>
#       <p begin="2852.76s" xml:id="p984" end="2854.599s">Administration there's a lot of tensions</p>
#       <p begin="2854.599s" xml:id="p985" end="2856.4s">and conflicts there that the left hand</p>
#       <p begin="2856.4s" xml:id="p986" end="2859.0s">doesn't necessarily support the the the</p>
#       <p begin="2859.0s" xml:id="p987" end="2860.96s">right hand so I don't think that the</p>
#       <p begin="2860.96s" xml:id="p988" end="2861.96s">Europeans will be looking to the</p>
#       <p begin="2861.96s" xml:id="p989" end="2864.48s">Americans to buy arms first unless the</p>
#       <p begin="2864.48s" xml:id="p990" end="2866.48s">Americans can reassure them and that</p>
#       <p begin="2866.48s" xml:id="p991" end="2868.04s">would require a fair bit of doing but</p>
#       <p begin="2868.04s" xml:id="p992" end="2869.8s">could be done and unless they can</p>
#       <p begin="2869.8s" xml:id="p993" end="2872.839s">expedite de expedite the deliveries to</p>
#       <p begin="2872.839s" xml:id="p994" end="2875.559s">them for instance the estonians wanted</p>
#       <p begin="2875.559s" xml:id="p995" end="2877.0s">to buy want to buy some of the these</p>
#       <p begin="2877.0s" xml:id="p996" end="2880.119s">high Mars rocket uh rocket systems and</p>
#       <p begin="2880.119s" xml:id="p997" end="2881.28s">they've been having a lot of trouble</p>
#       <p begin="2881.28s" xml:id="p998" end="2884.04s">getting good de good delivery dates from</p>
#       <p begin="2884.04s" xml:id="p999" end="2885.4s">the Americans and now talking about</p>
#       <p begin="2885.4s" xml:id="p1000" end="2887.16s">buying them from the south Koreans I</p>
#       <p begin="2887.16s" xml:id="p1001" end="2888.16s">think that they're doing a bit of a</p>
#       <p begin="2888.16s" xml:id="p1002" end="2889.76s">bargaining approach there but</p>
#       <p begin="2889.76s" xml:id="p1003" end="2891.8s">nonetheless it does show there are some</p>
#       <p begin="2891.8s" xml:id="p1004" end="2893.76s">options out there and countries like</p>
#       <p begin="2893.76s" xml:id="p1005" end="2895.8s">Poland have certainly moved to buy South</p>
#       <p begin="2895.8s" xml:id="p1006" end="2899.0s">Korean gear as well so I think that the</p>
#       <p begin="2899.0s" xml:id="p1007" end="2902.119s">American Arms networks into uh arm sales</p>
#       <p begin="2902.119s" xml:id="p1008" end="2904.24s">into Europe have reached a high point</p>
#       <p begin="2904.24s" xml:id="p1009" end="2905.88s">and they'll probably probably declin</p>
#       <p begin="2905.88s" xml:id="p1010" end="2908.04s">from here</p>
#       <p begin="2908.04s" xml:id="p1011" end="2909.96s">and the wraps up East Asia tonight this</p>
#       <p begin="2909.96s" xml:id="p1012" end="2911.559s">Monday don't forget your headlines</p>
#       <p begin="2911.559s" xml:id="p1013" end="2914.24s">anytime at cna. Asia and look us up on</p>
#       <p begin="2914.24s" xml:id="p1014" end="2915.88s">Facebook and on YouTube thanks for</p>
#       <p begin="2915.88s" xml:id="p1015" end="2918.88s">watching</p>
#       <p begin="2919.16s" xml:id="p1016" end="2933.31s">[Music]</p>
#     </div>
#   </body>
# </tt>
